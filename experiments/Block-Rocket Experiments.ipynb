# %% [markdown]
# # **Block-Rocket**

# %% [markdown]
# The benchmark workbook testing CNN-ResBiGRU found that there is almost no performance improvement when using more than 1 ResBiGRU block. In fact, when using 3 ResBiGRU blocks, the performance on the validation data actually worsened. Therefore, in the experiments below, we use 1 ResBiGRU block unless stated otherwise.

# %% [markdown]
# ## **Initialisation**

# %%
pip install sktime==0.31.0
# Out:
# Collecting sktime==0.31.0
#   Downloading sktime-0.31.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: joblib<1.5,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from sktime==0.31.0) (1.4.2)
# Requirement already satisfied: numpy<2.1,>=1.21 in /usr/local/lib/python3.10/dist-packages (from sktime==0.31.0) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sktime==0.31.0) (24.1)
# Requirement already satisfied: pandas<2.3.0,>=1.1 in /usr/local/lib/python3.10/dist-packages (from sktime==0.31.0) (2.1.4)
# Collecting scikit-base<0.9.0,>=0.6.1 (from sktime==0.31.0)
#   Downloading scikit_base-0.8.3-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: scikit-learn<1.6.0,>=0.24 in /usr/local/lib/python3.10/dist-packages (from sktime==0.31.0) (1.3.2)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in /usr/local/lib/python3.10/dist-packages (from sktime==0.31.0) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3.0,>=1.1->sktime==0.31.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3.0,>=1.1->sktime==0.31.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3.0,>=1.1->sktime==0.31.0) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.6.0,>=0.24->sktime==0.31.0) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<2.3.0,>=1.1->sktime==0.31.0) (1.16.0)
# Downloading sktime-0.31.0-py3-none-any.whl (24.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 70.2 MB/s eta 0:00:00
# Downloading scikit_base-0.8.3-py3-none-any.whl (136 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.2/136.2 kB 10.3 MB/s eta 0:00:00
# Installing collected packages: scikit-base, sktime
# Successfully installed scikit-base-0.8.3 sktime-0.31.0

# %%
import os
import numpy as np
import pickle
import itertools
from tqdm import tqdm
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.decomposition import PCA
from sktime.transformations.panel.rocket import MiniRocketMultivariate
from keras.models import Model
from keras.losses import CategoricalCrossentropy
from keras.metrics import Accuracy
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2
from keras.layers import Input, Layer, Concatenate, Lambda, Conv1D, MaxPool1D, ReLU, BatchNormalization, LayerNormalization, Dropout, Add, Dense, GlobalMaxPooling1D, Bidirectional, GRU

np.random.seed(123)
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
#You MUST run this command before reading in any data from Google Drive
from google.colab import files
from google.colab import drive
import pandas as pd
drive.mount('/content/drive', force_remount=True)
os.chdir('/content/drive/My Drive/Colab Notebooks/Thesis/experiments')

# %run ../sys_configs.ipynb
# %run ../plots.ipynb
# Out:
# Mounted at /content/drive

# %%
with open('../data/train.npy', 'rb') as f:
    x_train = np.load(f)
    y_train = np.load(f).astype(np.int64)
sz, dim = x_train.shape[1:]

with open('../data/val.npy', 'rb') as f:
    x_val = np.load(f)
    y_val = np.load(f).astype(np.int64)

with open('../data/test.npy', 'rb') as f:
    x_test = np.load(f)
    y_test = np.load(f).astype(np.int64)

classes = np.unique(y_train)

N_train = len(y_train)
N_val = len(y_val)
N_test = len(y_test)

# %%
# Convert the labels to tensors
train_labels_tf = tf.one_hot(y_train, 31, dtype=tf.float32)
val_labels_tf = tf.one_hot(y_val, 31, dtype=tf.float32)
test_labels_tf = tf.one_hot(y_test, 31, dtype=tf.float32)

# %%
C = len(set(y_train)) # Number of classes

# %% [markdown]
# #### **Prepare train & validation datasets**

# %% [markdown]
# We first produce the raw and first order differenced datasets.

# %%
# Convert the raw dataset to tensors
train_raw_tf = tf.convert_to_tensor(x_train[:, :-1, :], dtype=tf.float32)
val_raw_tf = tf.convert_to_tensor(x_val[:, :-1, :], dtype=tf.float32)
test_raw_tf = tf.convert_to_tensor(x_test[:, :-1, :], dtype=tf.float32)

# %%
# Compute the first order differenced dataset
x_train_diff = np.diff(x_train, axis = 1)
x_val_diff = np.diff(x_val, axis = 1)
x_test_diff = np.diff(x_test, axis = 1)

# %%
# Convert the first order differenced dataset to tensors
train_diff_tf = tf.convert_to_tensor(x_train_diff, dtype=tf.float32)
val_diff_tf = tf.convert_to_tensor(x_val_diff, dtype=tf.float32)
test_diff_tf = tf.convert_to_tensor(x_test_diff, dtype=tf.float32)

# %% [markdown]
# #### **Prepare Rocket transformation train & validation datasets**

# %% [markdown]
# We use the *sktime* MiniRocket implementation, which is the same implementation introduced in the MiniRocket paper.

# %%
# Transpose the train and validation data as the format needs to be N x D x (T - 1)
x_train_ = x_train[:, :-1, :].transpose((0, 2, 1))
x_val_ = x_val[:, :-1, :].transpose((0, 2, 1))
x_test_ = x_test[:, :-1, :].transpose((0, 2, 1))

x_train_diff_ = x_train_diff.transpose((0, 2, 1))
x_val_diff_ = x_val_diff.transpose((0, 2, 1))
x_test_diff_ = x_test_diff.transpose((0, 2, 1))

# %%
# Compute the MiniRocket transform and transform to tensors
minirocket_multi = MiniRocketMultivariate(num_kernels = 10000, max_dilations_per_kernel = 32)
minirocket_multi.fit(x_train_)

train_rocket_np = minirocket_multi.transform(x_train_)
val_rocket_np = minirocket_multi.transform(x_val_)
test_rocket_np = minirocket_multi.transform(x_test_)

train_rocket_tf = tf.convert_to_tensor(train_rocket_np, dtype = tf.float32)
val_rocket_tf = tf.convert_to_tensor(val_rocket_np, dtype = tf.float32)
test_rocket_tf = tf.convert_to_tensor(test_rocket_np, dtype = tf.float32)

train_rocket_diff_np = minirocket_multi.transform(x_train_diff_)
val_rocket_diff_np = minirocket_multi.transform(x_val_diff_)
test_rocket_diff_np = minirocket_multi.transform(x_test_diff_)

train_rocket_diff_tf = tf.convert_to_tensor(train_rocket_diff_np, dtype = tf.float32)
val_rocket_diff_tf = tf.convert_to_tensor(val_rocket_diff_np, dtype = tf.float32)
test_rocket_diff_tf = tf.convert_to_tensor(test_rocket_diff_np, dtype = tf.float32)

# %% [markdown]
# #### **Prepare PCA transformation train & validation datasets**

# %%
pca_rocket = PCA(n_components=128)
pca_rocket.fit(train_rocket_np)

pca_diff_rocket = PCA(n_components=128)
pca_diff_rocket.fit(train_rocket_diff_np)
# Out:
# PCA(n_components=128)

# %%
train_pca_np = pca_rocket.transform(train_rocket_np)
val_pca_np = pca_rocket.transform(val_rocket_np)
test_pca_np = pca_rocket.transform(test_rocket_np)

train_pca_diff_np = pca_diff_rocket.transform(train_rocket_diff_np)
val_pca_diff_np = pca_diff_rocket.transform(val_rocket_diff_np)
test_pca_diff_np = pca_diff_rocket.transform(test_rocket_diff_np)

# %%
train_pca_tf = tf.convert_to_tensor(train_pca_np, dtype = tf.float32)
val_pca_tf = tf.convert_to_tensor(val_pca_np, dtype = tf.float32)
test_pca_tf = tf.convert_to_tensor(test_pca_np, dtype = tf.float32)

train_pca_diff_tf = tf.convert_to_tensor(train_pca_diff_np, dtype = tf.float32)
val_pca_diff_tf = tf.convert_to_tensor(val_pca_diff_np, dtype = tf.float32)
test_pca_diff_tf = tf.convert_to_tensor(test_pca_diff_np, dtype = tf.float32)

# %% [markdown]
# #### **Combine input datasets**

# %% [markdown]
# We now prepare different Tensorflow datasets for the experiments in this workbook.

# %% [markdown]
# **Dataset 1: Raw Time Series**

# %%
train_raw_ds = tf.data.Dataset.from_tensor_slices((train_raw_tf, train_labels_tf))
val_raw_ds = tf.data.Dataset.from_tensor_slices((val_raw_tf, val_labels_tf))
test_raw_ds = tf.data.Dataset.from_tensor_slices((test_raw_tf, test_labels_tf))

train_raw_ds = train_raw_ds.shuffle(500)

train_raw_ds = train_raw_ds.padded_batch(64)
val_raw_ds = val_raw_ds.padded_batch(64)
test_raw_ds = test_raw_ds.padded_batch(64)

# %% [markdown]
# **Dataset 2: Differenced time series**

# %%
train_diff_ds = tf.data.Dataset.from_tensor_slices((train_diff_tf, train_labels_tf))
val_diff_ds = tf.data.Dataset.from_tensor_slices((val_diff_tf, val_labels_tf))
test_diff_ds = tf.data.Dataset.from_tensor_slices((test_diff_tf, test_labels_tf))

train_diff_ds = train_diff_ds.shuffle(500)

train_diff_ds = train_diff_ds.padded_batch(64)
val_diff_ds = val_diff_ds.padded_batch(64)
test_diff_ds = test_diff_ds.padded_batch(64)

# %% [markdown]
# **Dataset 3: Raw + Differenced Time Series**

# %%
train_rd_ds = tf.data.Dataset.from_tensor_slices((train_raw_tf, train_diff_tf, train_labels_tf))
val_rd_ds = tf.data.Dataset.from_tensor_slices((val_raw_tf, val_diff_tf, val_labels_tf))
test_rd_ds = tf.data.Dataset.from_tensor_slices((test_raw_tf, test_diff_tf, test_labels_tf))

# Map function to process the dataset elements
def map_rd(raw, diff, label):
    return {"raw": raw, "diff": diff}, label

# Apply the mapping function
train_rd_ds = train_rd_ds.map(map_rd)
val_rd_ds = val_rd_ds.map(map_rd)
test_rd_ds = test_rd_ds.map(map_rd)

train_rd_ds = train_rd_ds.shuffle(500)

train_rd_ds = train_rd_ds.padded_batch(64)
val_rd_ds = val_rd_ds.padded_batch(64)
test_rd_ds = test_rd_ds.padded_batch(64)

# %% [markdown]
# **Dataset 4: Raw + Rocket PCA Transformation Time Series**

# %%
train_rr_ds = tf.data.Dataset.from_tensor_slices((train_raw_tf, train_pca_tf, train_labels_tf))
val_rr_ds = tf.data.Dataset.from_tensor_slices((val_raw_tf, val_pca_tf, val_labels_tf))
test_rr_ds = tf.data.Dataset.from_tensor_slices((test_raw_tf, test_pca_tf, test_labels_tf))

# Map function to process the dataset elements
def map_rr(raw, pca, label):
    return {"raw": raw, "pca": pca}, label

# Apply the mapping function
train_rr_ds = train_rr_ds.map(map_rr)
val_rr_ds = val_rr_ds.map(map_rr)
test_rr_ds = test_rr_ds.map(map_rr)

train_rr_ds = train_rr_ds.shuffle(500)

train_rr_ds = train_rr_ds.padded_batch(64)
val_rr_ds = val_rr_ds.padded_batch(64)
test_rr_ds = test_rr_ds.padded_batch(64)

# %% [markdown]
# **Dataset 5: Raw + Differenced + Rocket PCA Transformation Time Series**

# %%
train_all_ds = tf.data.Dataset.from_tensor_slices((train_raw_tf, train_diff_tf, train_pca_tf, train_pca_diff_tf, train_labels_tf))
val_all_ds = tf.data.Dataset.from_tensor_slices((val_raw_tf, val_diff_tf, val_pca_tf, val_pca_diff_tf, val_labels_tf))
test_all_ds = tf.data.Dataset.from_tensor_slices((test_raw_tf, test_diff_tf, test_pca_tf, test_pca_diff_tf, test_labels_tf))

# Map function to process the dataset elements
def map_all(raw, diff, pca, pca_diff, label):
    return {"raw": raw, "diff": diff, "pca": pca, "pca_diff": pca_diff}, label

# Apply the mapping function
train_all_ds = train_all_ds.map(map_all)
val_all_ds = val_all_ds.map(map_all)
test_all_ds = test_all_ds.map(map_all)

train_all_ds = train_all_ds.shuffle(500)

train_all_ds = train_all_ds.padded_batch(64)
val_all_ds = val_all_ds.padded_batch(64)
test_all_ds = test_all_ds.padded_batch(64)

# %% [markdown]
# ## **Set up standard CNN-ResBiGRU blocks**

# %%
class ConvBlock(Layer):

    def __init__(self, num_filters, **kwargs):
        super().__init__(**kwargs)
        self.num_filters = num_filters

    def build(self, input_shape): # Tensorflow calls this method automatically when the object is defined
        self.conv = Conv1D(self.num_filters, kernel_size=10, strides = 1, padding="same")
        self.batch_norm = BatchNormalization()
        self.max_pool = MaxPool1D(pool_size=3, strides=1, padding="same")
        self.dropout = Dropout(0.25)

    def call(self, input):
        x = self.conv(input)
        x = self.batch_norm(x)
        x = self.max_pool(x)
        output = self.dropout(x)
        return output

# %%
class ResBiGRU(Layer):

    def __init__(self, h1_units, h2_units, **kwargs):
        super().__init__(**kwargs)
        self.h1_units = h1_units
        self.h2_units = h2_units

    def build(self, input_shape): # Tensorflow calls this method automatically when the object is defined
        self.gru_1 =  Bidirectional(GRU(self.h1_units, activation = None, return_sequences=True), merge_mode=None)
        self.gru_2a = GRU(self.h2_units, activation = None, return_sequences=True)
        self.gru_2b = GRU(self.h2_units, activation = None, return_sequences=True)
        self.layer_norm = LayerNormalization()

    def call(self, input):
        # In the first (hidden) RNN layer, apply the forward and backward GRU layers concurrently
        z_forward, z_backward = self.gru_1(input)

        # In the second (hidden) RNN layer, apply the forward and backward GRU layers separately
        z2_forward = self.gru_2a(z_forward)
        z2_backward = self.gru_2b(z_backward)

        # Add the output of the first RNN layer to the output of the second RNN layer
        z_forward = Add()([z_forward, z2_forward])
        z_backward = Add()([z_backward, z2_backward])

        z_forward = self.layer_norm(z_forward)
        z_backward = self.layer_norm(z_backward)

        output = tf.concat([z_forward, z_backward], axis = 2)
        return output

# %%
# We use early stopping as CNNResBiGRU is a high parameter network, so requires many epochs to train.
earlystopping = EarlyStopping(monitor='val_accuracy', patience=15)

# The previous benchmark paper also made use of ReduceLROnPlateau which reduces the lesrning rate when the loss plateaus.
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=10e-5)

# %% [markdown]
# ## **Experiment 1: ResBiGRU (raw vs differenced vs raw + differenced time series)**

# %% [markdown]
# The purpose of this experiment is to determine whether the first order differenced time series improves the validation performance of the ResBiGRU model.
#
# To combine the two channels, which run parallel, concatenate them before applying a Dense layer at the end.

# %% [markdown]
# #### **Experiment 1.1: Raw time series**

# %% [markdown]
# This is the same model per the benchmark workbook on CNN-ResBiGRU. Also, we already applied it to raw time series in the benchmark workbook, but do so here again for easy comparison.

# %%
def CNNResBiGRU(shape):
    block1_input_layer = Input(shape=shape)

    layer = ConvBlock(num_filters = 32, name = "ConvBlock")(block1_input_layer)

    # The architecture extensively factors in the gradient vanishing problem.
    layer = ResBiGRU(h1_units = 32, h2_units = 32, name = "ResBiGRU1")(layer)

    layer = GlobalMaxPooling1D()(layer)
    output_layer = Dense(C, activation="softmax")(layer)
    return Model(inputs=block1_input_layer, outputs=output_layer)

# %%
CNNResBiGRU_model = CNNResBiGRU(shape = (sz - 1, dim))
CNNResBiGRU_model.compile(optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, clipvalue = 1.0), loss='categorical_crossentropy', metrics=['accuracy'])
history = CNNResBiGRU_model.fit(train_raw_ds, validation_data=val_raw_ds, epochs=25, verbose = 1, callbacks = [earlystopping, reduce_lr])
# Out:
# Epoch 1/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 73s 236ms/step - accuracy: 0.1727 - loss: 3.2107 - val_accuracy: 0.4411 - val_loss: 1.9323 - learning_rate: 0.0010
# Epoch 2/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.5040 - loss: 1.7296 - val_accuracy: 0.5668 - val_loss: 1.3701 - learning_rate: 0.0010
# Epoch 3/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - accuracy: 0.6261 - loss: 1.2656 - val_accuracy: 0.6609 - val_loss: 1.0744 - learning_rate: 0.0010
# Epoch 4/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.7267 - loss: 0.9660 - val_accuracy: 0.6774 - val_loss: 0.9315 - learning_rate: 0.0010
# Epoch 5/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 136ms/step - accuracy: 0.7844 - loss: 0.7610 - val_accuracy: 0.7011 - val_loss: 0.8597 - learning_rate: 0.0010
# Epoch 6/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step - accuracy: 0.8505 - loss: 0.5883 - val_accuracy: 0.7069 - val_loss: 0.8348 - learning_rate: 0.0010
# Epoch 7/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - accuracy: 0.8820 - loss: 0.4612 - val_accuracy: 0.7141 - val_loss: 0.7947 - learning_rate: 0.0010
# Epoch 8/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - accuracy: 0.9111 - loss: 0.3790 - val_accuracy: 0.7313 - val_loss: 0.7340 - learning_rate: 0.0010
# Epoch 9/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 134ms/step - accuracy: 0.9263 - loss: 0.3142 - val_accuracy: 0.7119 - val_loss: 0.7696 - learning_rate: 0.0010
# Epoch 10/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9430 - loss: 0.2542 - val_accuracy: 0.7076 - val_loss: 0.7969 - learning_rate: 0.0010
# Epoch 11/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.9456 - loss: 0.2335 - val_accuracy: 0.7213 - val_loss: 0.7660 - learning_rate: 0.0010
# Epoch 12/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9559 - loss: 0.1932 - val_accuracy: 0.7299 - val_loss: 0.6943 - learning_rate: 5.0000e-04
# Epoch 13/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9666 - loss: 0.1630 - val_accuracy: 0.7385 - val_loss: 0.7078 - learning_rate: 5.0000e-04
# Epoch 14/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - accuracy: 0.9722 - loss: 0.1490 - val_accuracy: 0.7464 - val_loss: 0.7046 - learning_rate: 5.0000e-04
# Epoch 15/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9746 - loss: 0.1338 - val_accuracy: 0.7471 - val_loss: 0.6971 - learning_rate: 5.0000e-04
# Epoch 16/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 127ms/step - accuracy: 0.9784 - loss: 0.1147 - val_accuracy: 0.7392 - val_loss: 0.7149 - learning_rate: 2.5000e-04
# Epoch 17/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - accuracy: 0.9779 - loss: 0.1132 - val_accuracy: 0.7414 - val_loss: 0.6982 - learning_rate: 2.5000e-04
# Epoch 18/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.9823 - loss: 0.1069 - val_accuracy: 0.7364 - val_loss: 0.7023 - learning_rate: 2.5000e-04
# Epoch 19/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - accuracy: 0.9815 - loss: 0.1054 - val_accuracy: 0.7392 - val_loss: 0.6875 - learning_rate: 1.2500e-04
# Epoch 20/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.9836 - loss: 0.1014 - val_accuracy: 0.7399 - val_loss: 0.6897 - learning_rate: 1.2500e-04
# Epoch 21/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.9862 - loss: 0.0949 - val_accuracy: 0.7385 - val_loss: 0.6894 - learning_rate: 1.2500e-04
# Epoch 22/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.9885 - loss: 0.0880 - val_accuracy: 0.7428 - val_loss: 0.7051 - learning_rate: 1.2500e-04
# Epoch 23/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - accuracy: 0.9841 - loss: 0.0929 - val_accuracy: 0.7385 - val_loss: 0.7049 - learning_rate: 1.0000e-04
# Epoch 24/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - accuracy: 0.9828 - loss: 0.0977 - val_accuracy: 0.7364 - val_loss: 0.7049 - learning_rate: 1.0000e-04
# Epoch 25/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 127ms/step - accuracy: 0.9877 - loss: 0.0834 - val_accuracy: 0.7349 - val_loss: 0.7011 - learning_rate: 1.0000e-04

# %%
CNNResBiGRU_results1_val = CNNResBiGRU_model.evaluate(val_raw_ds, batch_size=128)
CNNResBiGRU_results1_test = CNNResBiGRU_model.evaluate(test_raw_ds, batch_size=128)
print("Validation Loss: {}\nValidation Accuracy: {}".format(*CNNResBiGRU_results1_val))
print("Test Loss: {}\nTest Accuracy: {}".format(*CNNResBiGRU_results1_test))
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.7286 - loss: 0.7559
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.6912 - loss: 1.0092
# Validation Loss: 0.7010752558708191
# Validation Accuracy: 0.7349137663841248
# Test Loss: 1.0123274326324463
# Test Accuracy: 0.6983824968338013

# %%
predictions1_val = CNNResBiGRU_model.predict(val_raw_tf, batch_size=128)
predictions1_test = CNNResBiGRU_model.predict(test_raw_tf, batch_size=128)

predictions1_val =tf.argmax(predictions1_val, axis = 1)
predictions1_test = tf.argmax(predictions1_test, axis = 1)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step

# %%
# Compare predictions against the targets
print("Validation Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions1_val), sum(np.equal(predictions1_val, y_val))))
print("Test Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions1_test), sum(np.equal(predictions1_test, y_test))))
# Out:
# Validation Data - Total predictions made: 1392. Number of correct predictions: 1023
# Test Data - Total predictions made: 1051. Number of correct predictions: 734

# %%
CNNResBiGRU_model.save('../models/BlockRocketExperiments/Experiment_1_1.keras')
with open('../models/BlockRocketExperiments/train_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %% [markdown]
# #### **Experiment 1.2: Differenced time series**

# %% [markdown]
# **Experiment 1.2.1: One ResBiGRU block**

# %%
CNNResBiGRU_model2 = CNNResBiGRU(shape = (sz - 1, dim)) # (sz - 1) as the data is differenced
CNNResBiGRU_model2.compile(optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08), loss='categorical_crossentropy', metrics=['accuracy'])
history2 = CNNResBiGRU_model2.fit(train_diff_ds, validation_data=val_diff_ds, epochs=25, verbose = 1, callbacks = [earlystopping, reduce_lr])
# Out:
# Epoch 1/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 26s 220ms/step - accuracy: 0.0493 - loss: 3.8918 - val_accuracy: 0.0395 - val_loss: 3.3224 - learning_rate: 0.0010
# Epoch 2/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.1635 - loss: 2.9758 - val_accuracy: 0.0790 - val_loss: 3.3825 - learning_rate: 0.0010
# Epoch 3/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.3082 - loss: 2.5351 - val_accuracy: 0.1228 - val_loss: 3.0560 - learning_rate: 0.0010
# Epoch 4/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.4515 - loss: 2.0351 - val_accuracy: 0.2421 - val_loss: 2.3863 - learning_rate: 0.0010
# Epoch 5/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.5626 - loss: 1.5935 - val_accuracy: 0.3333 - val_loss: 2.1512 - learning_rate: 0.0010
# Epoch 6/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.6619 - loss: 1.2148 - val_accuracy: 0.4591 - val_loss: 1.7191 - learning_rate: 0.0010
# Epoch 7/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - accuracy: 0.7322 - loss: 0.9443 - val_accuracy: 0.4950 - val_loss: 1.5044 - learning_rate: 0.0010
# Epoch 8/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - accuracy: 0.8033 - loss: 0.7475 - val_accuracy: 0.5467 - val_loss: 1.3756 - learning_rate: 0.0010
# Epoch 9/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step - accuracy: 0.8328 - loss: 0.6134 - val_accuracy: 0.5603 - val_loss: 1.2943 - learning_rate: 0.0010
# Epoch 10/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.8725 - loss: 0.5059 - val_accuracy: 0.5905 - val_loss: 1.2064 - learning_rate: 0.0010
# Epoch 11/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.8787 - loss: 0.4472 - val_accuracy: 0.6006 - val_loss: 1.1561 - learning_rate: 0.0010
# Epoch 12/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 118ms/step - accuracy: 0.9159 - loss: 0.3571 - val_accuracy: 0.6027 - val_loss: 1.1800 - learning_rate: 0.0010
# Epoch 13/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 127ms/step - accuracy: 0.9283 - loss: 0.3220 - val_accuracy: 0.6149 - val_loss: 1.1572 - learning_rate: 0.0010
# Epoch 14/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9398 - loss: 0.2678 - val_accuracy: 0.6257 - val_loss: 1.0890 - learning_rate: 0.0010
# Epoch 15/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9453 - loss: 0.2332 - val_accuracy: 0.6185 - val_loss: 1.1281 - learning_rate: 0.0010

# %%
CNNResBiGRU_results2_val = CNNResBiGRU_model2.evaluate(val_diff_ds, batch_size=128)
CNNResBiGRU_results2_test = CNNResBiGRU_model2.evaluate(test_diff_ds, batch_size=128)
print("Validation Loss: {}\nValidation Accuracy: {}".format(*CNNResBiGRU_results2_val))
print("Test Loss: {}\nTest Accuracy: {}".format(*CNNResBiGRU_results2_test))
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5996 - loss: 1.1732
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.5711 - loss: 1.3135
# Validation Loss: 1.128129005432129
# Validation Accuracy: 0.618534505367279
# Test Loss: 1.315980315208435
# Test Accuracy: 0.5842055082321167

# %%
predictions2_val = CNNResBiGRU_model2.predict(val_diff_tf, batch_size=128)
predictions2_test = CNNResBiGRU_model2.predict(test_diff_tf, batch_size=128)

predictions2_val =tf.argmax(predictions2_val, axis = 1)
predictions2_test = tf.argmax(predictions2_test, axis = 1)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step

# %%
# Compare predictions against the targets
print("Validation Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions2_val), sum(np.equal(predictions2_val, y_val))))
print("Test Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions2_test), sum(np.equal(predictions2_test, y_test))))
# Out:
# Validation Data - Total predictions made: 1392. Number of correct predictions: 861
# Test Data - Total predictions made: 1051. Number of correct predictions: 614

# %%
CNNResBiGRU_model2.save('../models/BlockRocketExperiments/Experiment_1_2_1.keras')
with open('../models/BlockRocketExperiments/train_history2.pkl', 'wb') as f:
    pickle.dump(history2.history, f)

# %% [markdown]
# The model manages to pick up on a signal within the differenced time series, but the performance falls well short of that from the same model applied on the raw time series. Perhaps more ResBiGRU blocks are needed to extract information from the differenced time series.

# %% [markdown]
# **Experiment 1.2.2: Two ResBiGRU blocks**

# %% [markdown]
# This is identical to experiment 1.2.1 except for the addition of a second ResBiGRU block.

# %%
def CNNResBiGRU2(shape):
    block1_input_layer = Input(shape=shape)

    layer = ConvBlock(num_filters = 32, name = "ConvBlock")(block1_input_layer)

    # The architecture extensively factors in the gradient vanishing problem.
    layer = ResBiGRU(h1_units = 32, h2_units = 32, name = "ResBiGRU1")(layer)
    layer = ResBiGRU(h1_units = 32, h2_units = 32, name = "ResBiGRU2")(layer)

    layer = GlobalMaxPooling1D()(layer)
    output_layer = Dense(C, activation="softmax")(layer)
    return Model(inputs=block1_input_layer, outputs=output_layer)

# %%
CNNResBiGRU_model3 = CNNResBiGRU2(shape = (sz - 1, dim)) # (sz - 1) as the data is differenced
CNNResBiGRU_model3.compile(optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08), loss='categorical_crossentropy', metrics=['accuracy'])
history3 = CNNResBiGRU_model3.fit(train_diff_ds, validation_data=val_diff_ds, epochs=25, verbose = 1)
# Out:
# Epoch 1/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 48s 436ms/step - accuracy: 0.0595 - loss: 3.6771 - val_accuracy: 0.0316 - val_loss: 4.1204
# Epoch 2/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 244ms/step - accuracy: 0.2151 - loss: 2.8445 - val_accuracy: 0.1149 - val_loss: 3.0403
# Epoch 3/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 251ms/step - accuracy: 0.4704 - loss: 1.9549 - val_accuracy: 0.3161 - val_loss: 2.1713
# Epoch 4/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 245ms/step - accuracy: 0.6684 - loss: 1.2453 - val_accuracy: 0.4612 - val_loss: 1.6708
# Epoch 5/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 245ms/step - accuracy: 0.7932 - loss: 0.8285 - val_accuracy: 0.5395 - val_loss: 1.3715
# Epoch 6/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 250ms/step - accuracy: 0.8569 - loss: 0.6015 - val_accuracy: 0.5496 - val_loss: 1.3895
# Epoch 7/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 245ms/step - accuracy: 0.9106 - loss: 0.4175 - val_accuracy: 0.6307 - val_loss: 1.1036
# Epoch 8/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 22s 268ms/step - accuracy: 0.9297 - loss: 0.3193 - val_accuracy: 0.6609 - val_loss: 1.0563
# Epoch 9/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 19s 244ms/step - accuracy: 0.9539 - loss: 0.2409 - val_accuracy: 0.6782 - val_loss: 1.0331
# Epoch 10/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 244ms/step - accuracy: 0.9596 - loss: 0.2001 - val_accuracy: 0.6810 - val_loss: 1.0352
# Epoch 11/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 244ms/step - accuracy: 0.9741 - loss: 0.1519 - val_accuracy: 0.6473 - val_loss: 1.1758
# Epoch 12/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 243ms/step - accuracy: 0.9788 - loss: 0.1222 - val_accuracy: 0.6710 - val_loss: 1.1084
# Epoch 13/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 250ms/step - accuracy: 0.9828 - loss: 0.1027 - val_accuracy: 0.6566 - val_loss: 1.2332
# Epoch 14/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 247ms/step - accuracy: 0.9802 - loss: 0.0935 - val_accuracy: 0.6832 - val_loss: 1.1086
# Epoch 15/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 247ms/step - accuracy: 0.9887 - loss: 0.0788 - val_accuracy: 0.6853 - val_loss: 1.0939
# Epoch 16/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 244ms/step - accuracy: 0.9936 - loss: 0.0550 - val_accuracy: 0.6882 - val_loss: 1.1496
# Epoch 17/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 244ms/step - accuracy: 0.9945 - loss: 0.0516 - val_accuracy: 0.7019 - val_loss: 1.1039
# Epoch 18/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 245ms/step - accuracy: 0.9959 - loss: 0.0355 - val_accuracy: 0.6839 - val_loss: 1.1887
# Epoch 19/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 244ms/step - accuracy: 0.9969 - loss: 0.0349 - val_accuracy: 0.6681 - val_loss: 1.2481
# Epoch 20/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 252ms/step - accuracy: 0.9961 - loss: 0.0297 - val_accuracy: 0.6846 - val_loss: 1.2008
# Epoch 21/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - accuracy: 0.9963 - loss: 0.0316 - val_accuracy: 0.6832 - val_loss: 1.1948
# Epoch 22/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 245ms/step - accuracy: 0.9965 - loss: 0.0318 - val_accuracy: 0.6832 - val_loss: 1.2118
# Epoch 23/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - accuracy: 0.9967 - loss: 0.0240 - val_accuracy: 0.6688 - val_loss: 1.3290
# Epoch 24/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 250ms/step - accuracy: 0.9922 - loss: 0.0402 - val_accuracy: 0.6904 - val_loss: 1.1918
# Epoch 25/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 244ms/step - accuracy: 0.9965 - loss: 0.0238 - val_accuracy: 0.6976 - val_loss: 1.2245

# %%
CNNResBiGRU_results3_val = CNNResBiGRU_model3.evaluate(val_diff_ds, batch_size=128)
CNNResBiGRU_results3_test = CNNResBiGRU_model3.evaluate(test_diff_ds, batch_size=128)
print("Validation Loss: {}\nValidation Accuracy: {}".format(*CNNResBiGRU_results3_val))
print("Test Loss: {}\nTest Accuracy: {}".format(*CNNResBiGRU_results3_test))
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.6916 - loss: 1.3214
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - accuracy: 0.6592 - loss: 1.4286
# Validation Loss: 1.2244813442230225
# Validation Accuracy: 0.6975574493408203
# Test Loss: 1.3822401762008667
# Test Accuracy: 0.6698382496833801

# %%
predictions3_val = CNNResBiGRU_model3.predict(val_diff_tf, batch_size=128)
predictions3_test = CNNResBiGRU_model3.predict(test_diff_tf, batch_size=128)

predictions3_val =tf.argmax(predictions3_val, axis = 1)
predictions3_test = tf.argmax(predictions3_test, axis = 1)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 329ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step

# %%
# Compare predictions against the targets
print("Validation Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions3_val), sum(np.equal(predictions3_val, y_val))))
print("Test Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions3_test), sum(np.equal(predictions3_test, y_test))))
# Out:
# Validation Data - Total predictions made: 1392. Number of correct predictions: 971
# Test Data - Total predictions made: 1051. Number of correct predictions: 704

# %% [markdown]
# The accuracy is very close to the accuracy on the raw (not differenced) time series, but some information was lost during the differencing process, resulting in an overall slightly poorer performance.

# %%
CNNResBiGRU_model3.save('../models/BlockRocketExperiments/Experiment_1_2_2.keras')
with open('../models/BlockRocketExperiments/train_history3.pkl', 'wb') as f:
    pickle.dump(history3.history, f)

# %% [markdown]
# #### **Experiment 1.3: Raw + differenced time series**

# %% [markdown]
# These experiments are intended to test whether using both the raw and first order differenced time series improves the performance of the resulting model. In experiment 1.2.2, it was observed that a second ResBiGRU block  the differenced time series

# %% [markdown]
# **Experiment 1.3.1: Combining after first Convolutional block**

# %%
def CNNResBiGRU3(shape_raw, shape_diff):
    block1_input_layer = Input(shape=shape_raw, name="raw")
    block2_input_layer = Input(shape=shape_diff, name="diff")

    layer_raw = ConvBlock(num_filters = 32, name = "ConvBlockRaw")(block1_input_layer)
    layer_diff = ConvBlock(num_filters = 32, name = "ConvBlockDiff")(block2_input_layer)

    # Concatenate the raw and differenced channels
    layer = Concatenate(axis = 2)([layer_raw, layer_diff])

    # The ResBIGRU blocks is repeated several times; the architecture extensively factors in the gradient vanishing problem.
    layer = ResBiGRU(h1_units = 32, h2_units = 32, name = "ResBiGRU1")(layer)
    layer = ResBiGRU(h1_units = 32, h2_units = 32, name = "ResBiGRU2")(layer)

    layer = GlobalMaxPooling1D()(layer)
    output_layer = Dense(C, activation="softmax")(layer)
    return Model(inputs=[block1_input_layer, block2_input_layer], outputs=output_layer)

# %%
CNNResBiGRU_model3 = CNNResBiGRU3(shape_raw = (sz - 1, dim), shape_diff = (sz - 1, dim)) # (sz - 1) as the data is differenced
CNNResBiGRU_model3.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ raw (InputLayer)          │ (None, 149, 6)         │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ diff (InputLayer)         │ (None, 149, 6)         │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ConvBlockRaw (ConvBlock)  │ (None, 149, 32)        │          2,080 │ raw[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ConvBlockDiff (ConvBlock) │ (None, 149, 32)        │          2,080 │ diff[0][0]             │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 149, 64)        │              0 │ ConvBlockRaw[0][0],    │
# │                           │                        │                │ ConvBlockDiff[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ResBiGRU1 (ResBiGRU)      │ (None, 149, 64)        │         31,552 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ResBiGRU2 (ResBiGRU)      │ (None, 149, 64)        │         31,552 │ ResBiGRU1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling1d_6    │ (None, 64)             │              0 │ ResBiGRU2[0][0]        │
# │ (GlobalMaxPooling1D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 31)             │          2,015 │ global_max_pooling1d_… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 69,279 (270.62 KB)
#  Trainable params: 69,151 (270.12 KB)
#  Non-trainable params: 128 (512.00 B)

# %%
CNNResBiGRU_model4 = CNNResBiGRU3(shape_raw = (sz - 1, dim), shape_diff = (sz - 1, dim))
CNNResBiGRU_model4.compile(optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08), loss='categorical_crossentropy', metrics=['accuracy'])
history4 = CNNResBiGRU_model4.fit(train_rd_ds, validation_data=val_rd_ds, epochs=25, verbose = 1, callbacks = [earlystopping, reduce_lr])
# Out:
# Epoch 1/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 50s 426ms/step - accuracy: 0.1941 - loss: 3.2244 - val_accuracy: 0.4382 - val_loss: 1.8027 - learning_rate: 0.0010
# Epoch 2/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 236ms/step - accuracy: 0.6309 - loss: 1.4091 - val_accuracy: 0.5740 - val_loss: 1.3011 - learning_rate: 0.0010
# Epoch 3/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 237ms/step - accuracy: 0.7539 - loss: 0.9187 - val_accuracy: 0.6774 - val_loss: 1.0542 - learning_rate: 0.0010
# Epoch 4/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 237ms/step - accuracy: 0.8439 - loss: 0.6243 - val_accuracy: 0.6983 - val_loss: 0.9013 - learning_rate: 0.0010
# Epoch 5/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 236ms/step - accuracy: 0.9059 - loss: 0.4232 - val_accuracy: 0.7076 - val_loss: 0.8448 - learning_rate: 0.0010
# Epoch 6/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 239ms/step - accuracy: 0.9405 - loss: 0.2939 - val_accuracy: 0.7234 - val_loss: 0.8046 - learning_rate: 0.0010
# Epoch 7/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 236ms/step - accuracy: 0.9678 - loss: 0.2084 - val_accuracy: 0.7284 - val_loss: 0.7240 - learning_rate: 0.0010
# Epoch 8/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 236ms/step - accuracy: 0.9827 - loss: 0.1514 - val_accuracy: 0.7306 - val_loss: 0.7247 - learning_rate: 0.0010
# Epoch 9/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 242ms/step - accuracy: 0.9800 - loss: 0.1198 - val_accuracy: 0.7500 - val_loss: 0.7156 - learning_rate: 0.0010
# Epoch 10/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 243ms/step - accuracy: 0.9877 - loss: 0.0962 - val_accuracy: 0.7464 - val_loss: 0.7068 - learning_rate: 0.0010
# Epoch 11/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 239ms/step - accuracy: 0.9934 - loss: 0.0720 - val_accuracy: 0.7522 - val_loss: 0.7064 - learning_rate: 0.0010
# Epoch 12/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 240ms/step - accuracy: 0.9940 - loss: 0.0526 - val_accuracy: 0.7601 - val_loss: 0.7431 - learning_rate: 0.0010
# Epoch 13/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 236ms/step - accuracy: 0.9949 - loss: 0.0428 - val_accuracy: 0.7522 - val_loss: 0.6935 - learning_rate: 0.0010
# Epoch 14/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 246ms/step - accuracy: 0.9935 - loss: 0.0421 - val_accuracy: 0.7471 - val_loss: 0.7517 - learning_rate: 0.0010
# Epoch 15/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 237ms/step - accuracy: 0.9957 - loss: 0.0372 - val_accuracy: 0.7543 - val_loss: 0.7217 - learning_rate: 0.0010
# Epoch 16/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 246ms/step - accuracy: 0.9968 - loss: 0.0250 - val_accuracy: 0.7651 - val_loss: 0.7362 - learning_rate: 0.0010
# Epoch 17/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 240ms/step - accuracy: 0.9989 - loss: 0.0203 - val_accuracy: 0.7665 - val_loss: 0.7191 - learning_rate: 5.0000e-04
# Epoch 18/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 236ms/step - accuracy: 0.9980 - loss: 0.0192 - val_accuracy: 0.7651 - val_loss: 0.7227 - learning_rate: 5.0000e-04
# Epoch 19/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 237ms/step - accuracy: 0.9988 - loss: 0.0162 - val_accuracy: 0.7644 - val_loss: 0.7602 - learning_rate: 5.0000e-04
# Epoch 20/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 237ms/step - accuracy: 0.9999 - loss: 0.0149 - val_accuracy: 0.7529 - val_loss: 0.7540 - learning_rate: 2.5000e-04
# Epoch 21/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 235ms/step - accuracy: 0.9994 - loss: 0.0125 - val_accuracy: 0.7708 - val_loss: 0.7627 - learning_rate: 2.5000e-04
# Epoch 22/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 238ms/step - accuracy: 0.9995 - loss: 0.0119 - val_accuracy: 0.7629 - val_loss: 0.7866 - learning_rate: 2.5000e-04
# Epoch 23/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 244ms/step - accuracy: 0.9994 - loss: 0.0117 - val_accuracy: 0.7629 - val_loss: 0.7830 - learning_rate: 1.2500e-04
# Epoch 24/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 237ms/step - accuracy: 0.9987 - loss: 0.0105 - val_accuracy: 0.7629 - val_loss: 0.7900 - learning_rate: 1.2500e-04
# Epoch 25/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 21s 245ms/step - accuracy: 0.9991 - loss: 0.0116 - val_accuracy: 0.7622 - val_loss: 0.7880 - learning_rate: 1.2500e-04

# %%
CNNResBiGRU_results4 = CNNResBiGRU_model4.evaluate(val_rd_ds, batch_size=128)
print("Validation Loss: {}\nValidation Accuracy: {}".format(*CNNResBiGRU_results4))
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7546 - loss: 0.8251
# Validation Loss: 0.7880142331123352
# Validation Accuracy: 0.7622126340866089

# %%
CNNResBiGRU_results4_val = CNNResBiGRU_model4.evaluate(val_rd_ds, batch_size=128)
CNNResBiGRU_results4_test = CNNResBiGRU_model4.evaluate(test_rd_ds, batch_size=128)
print("Validation Loss: {}\nValidation Accuracy: {}".format(*CNNResBiGRU_results4_val))
print("Test Loss: {}\nTest Accuracy: {}".format(*CNNResBiGRU_results4_test))
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.7546 - loss: 0.8251
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.7234 - loss: 1.0950
# Validation Loss: 0.7880142331123352
# Validation Accuracy: 0.7622126340866089
# Test Loss: 1.0641939640045166
# Test Accuracy: 0.7250238060951233

# %%
predictions4_val = CNNResBiGRU_model4.predict((val_diff_tf, val_raw_tf), batch_size=128)
predictions4_test = CNNResBiGRU_model4.predict((test_diff_tf, test_raw_tf), batch_size=128)

predictions4_val =tf.argmax(predictions4_val, axis = 1)
predictions4_test = tf.argmax(predictions4_test, axis = 1)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step

# %%
# Compare predictions against the targets
print("Validation Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions4_val), sum(np.equal(predictions4_val, y_val))))
print("Test Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions4_test), sum(np.equal(predictions4_test, y_test))))
# Out:
# Validation Data - Total predictions made: 1392. Number of correct predictions: 1061
# Test Data - Total predictions made: 1051. Number of correct predictions: 762

# %% [markdown]
# The closer a classifier gets towards a perfect classification rate, the harder to incrementally improve the classifier. This approach beats using the raw time series alone, indicating there is complementary information in the differenced time series that does not exist in the raw time series.

# %%
CNNResBiGRU_model4.save('../models/BlockRocketExperiments/Experiment_1_3_1.keras')
with open('../models/BlockRocketExperiments/train_history4.pkl', 'wb') as f:
    pickle.dump(history4.history, f)

# %% [markdown]
# **Experiment 1.3.2: Combining after ResBiGRU block**

# %%
def CNNResBiGRU4(shape_raw, shape_diff):
    T_raw, dim_raw = shape_raw

    block1_input_layer = Input(shape=shape_raw, name="raw")
    block2_input_layer = Input(shape=shape_diff, name="diff")

    layer_raw = ConvBlock(num_filters = 32, name = "ConvBlockRaw")(block1_input_layer)
    layer_diff = ConvBlock(num_filters = 32, name = "ConvBlockDiff")(block2_input_layer)

    # The ResBiGRU block is applied once to the raw time series. This was observed to be optimal in the CNN-ResBiGRU workbook.
    layer_raw = ResBiGRU(h1_units = 32, h2_units = 32, name = "ResBiGRU1")(layer_raw)

    # The ResBIGRU block is applied twice to the differenced time series. This was observed to be optimal during experiments 1.2.1 and 1.2.2
    layer_diff = ResBiGRU(h1_units = 32, h2_units = 32, name = "ResBiGRU2")(layer_diff)
    layer_diff = ResBiGRU(h1_units = 32, h2_units = 32, name = "ResBiGRU3")(layer_diff)

    # Concatenate the raw and differenced channels
    layer = Concatenate(axis = 2)([layer_raw, layer_diff])

    layer = GlobalMaxPooling1D()(layer)
    output_layer = Dense(C, activation="softmax")(layer)
    return Model(inputs=[block1_input_layer, block2_input_layer], outputs=output_layer)

# %%
CNNResBiGRU_model5 = CNNResBiGRU4(shape_raw = (sz - 1, dim), shape_diff = (sz - 1, dim))
CNNResBiGRU_model5.compile(optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08), loss='categorical_crossentropy', metrics=['accuracy'])
history5 = CNNResBiGRU_model5.fit(train_rd_ds, validation_data=val_rd_ds, epochs=25, verbose = 1)
# Out:
# Epoch 1/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 81s 737ms/step - accuracy: 0.1915 - loss: 3.5210 - val_accuracy: 0.4483 - val_loss: 1.8381
# Epoch 2/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 45s 387ms/step - accuracy: 0.5585 - loss: 1.4810 - val_accuracy: 0.5769 - val_loss: 1.3425
# Epoch 3/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 39s 357ms/step - accuracy: 0.7304 - loss: 0.9589 - val_accuracy: 0.6674 - val_loss: 1.0245
# Epoch 4/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 24s 353ms/step - accuracy: 0.8244 - loss: 0.6521 - val_accuracy: 0.6976 - val_loss: 0.8164
# Epoch 5/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 371ms/step - accuracy: 0.9055 - loss: 0.4289 - val_accuracy: 0.6968 - val_loss: 0.8025
# Epoch 6/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 40s 357ms/step - accuracy: 0.9375 - loss: 0.3107 - val_accuracy: 0.7205 - val_loss: 0.6888
# Epoch 7/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 358ms/step - accuracy: 0.9569 - loss: 0.2211 - val_accuracy: 0.7435 - val_loss: 0.6822
# Epoch 8/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 363ms/step - accuracy: 0.9654 - loss: 0.1659 - val_accuracy: 0.7342 - val_loss: 0.6555
# Epoch 9/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 361ms/step - accuracy: 0.9793 - loss: 0.1235 - val_accuracy: 0.7759 - val_loss: 0.6314
# Epoch 10/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 359ms/step - accuracy: 0.9852 - loss: 0.0996 - val_accuracy: 0.7471 - val_loss: 0.6451
# Epoch 11/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 356ms/step - accuracy: 0.9849 - loss: 0.0882 - val_accuracy: 0.7672 - val_loss: 0.6441
# Epoch 12/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 25s 368ms/step - accuracy: 0.9871 - loss: 0.0676 - val_accuracy: 0.7672 - val_loss: 0.6768
# Epoch 13/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 366ms/step - accuracy: 0.9915 - loss: 0.0574 - val_accuracy: 0.7399 - val_loss: 0.6925
# Epoch 14/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 362ms/step - accuracy: 0.9934 - loss: 0.0468 - val_accuracy: 0.7579 - val_loss: 0.6392
# Epoch 15/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 359ms/step - accuracy: 0.9949 - loss: 0.0407 - val_accuracy: 0.7486 - val_loss: 0.6872
# Epoch 16/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 358ms/step - accuracy: 0.9940 - loss: 0.0366 - val_accuracy: 0.7486 - val_loss: 0.7337
# Epoch 17/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 358ms/step - accuracy: 0.9951 - loss: 0.0314 - val_accuracy: 0.7349 - val_loss: 0.7172
# Epoch 18/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 358ms/step - accuracy: 0.9969 - loss: 0.0250 - val_accuracy: 0.7493 - val_loss: 0.6948
# Epoch 19/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 24s 356ms/step - accuracy: 0.9973 - loss: 0.0203 - val_accuracy: 0.7572 - val_loss: 0.7013
# Epoch 20/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 360ms/step - accuracy: 0.9970 - loss: 0.0220 - val_accuracy: 0.7371 - val_loss: 0.8119
# Epoch 21/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 359ms/step - accuracy: 0.9985 - loss: 0.0206 - val_accuracy: 0.7457 - val_loss: 0.7898
# Epoch 22/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 362ms/step - accuracy: 0.9976 - loss: 0.0199 - val_accuracy: 0.7471 - val_loss: 0.7738
# Epoch 23/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 358ms/step - accuracy: 0.9970 - loss: 0.0199 - val_accuracy: 0.7256 - val_loss: 0.7821
# Epoch 24/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 355ms/step - accuracy: 0.9990 - loss: 0.0118 - val_accuracy: 0.7399 - val_loss: 0.7527
# Epoch 25/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 41s 358ms/step - accuracy: 0.9954 - loss: 0.0163 - val_accuracy: 0.7313 - val_loss: 0.8295

# %%
CNNResBiGRU_results5_val = CNNResBiGRU_model5.evaluate(val_rd_ds, batch_size=128)
CNNResBiGRU_results5_test = CNNResBiGRU_model5.evaluate(test_rd_ds, batch_size=128)
print("Validation Loss: {}\nValidation Accuracy: {}".format(*CNNResBiGRU_results5_val))
print("Test Loss: {}\nTest Accuracy: {}".format(*CNNResBiGRU_results5_test))
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.7108 - loss: 0.8613
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.7240 - loss: 0.9968
# Validation Loss: 0.8295275568962097
# Validation Accuracy: 0.7313218116760254
# Test Loss: 0.9738443493843079
# Test Accuracy: 0.7250238060951233

# %%
predictions5_val = CNNResBiGRU_model5.predict((val_diff_tf, val_raw_tf), batch_size=128)
predictions5_test = CNNResBiGRU_model5.predict((test_diff_tf, test_raw_tf), batch_size=128)

predictions5_val =tf.argmax(predictions5_val, axis = 1)
predictions5_test = tf.argmax(predictions5_test, axis = 1)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 438ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 286ms/step

# %%
# Compare predictions against the targets
print("Validation Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions5_val), sum(np.equal(predictions5_val, y_val))))
print("Test Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions5_test), sum(np.equal(predictions5_test, y_test))))
# Out:
# Validation Data - Total predictions made: 1392. Number of correct predictions: 1018
# Test Data - Total predictions made: 1051. Number of correct predictions: 762

# %% [markdown]
# This has the same performance as the model which combined the two streams after the first convolutional block. This may be because this current model has a greater number of parameters (an extra ResBiGRU block) and is unable to generalise to unseen validation data as effectively.

# %%
CNNResBiGRU_model5.save('../models/BlockRocketExperiments/Experiment_1_3_2.keras')
with open('../models/BlockRocketExperiments/train_history5.pkl', 'wb') as f:
    pickle.dump(history5.history, f)

# %% [markdown]
# ## **Experiment 2: ResBiGRU (zero vs two preceding convolutional blocks)**

# %% [markdown]
# In this set of experiments, we do not need to test the case of exactly 1 preceding convolutional block as this was tested in experiment 1.1. We are interested in determining the effect changing the number of preceding convolutional blocks has on the generalisation ability of the model.

# %% [markdown]
# #### **Experiment 2.1: 0 preceding convolutional blocks**

# %%
def CNNResBiGRU5(shape):
    block1_input_layer = Input(shape=shape)

    # The architecture extensively factors in the gradient vanishing problem.
    layer = ResBiGRU(h1_units = 32, h2_units = 32, name = "ResBiGRU1")(block1_input_layer)

    layer = GlobalMaxPooling1D()(layer)
    output_layer = Dense(C, activation="softmax")(layer)
    return Model(inputs=block1_input_layer, outputs=output_layer)

# %%
CNNResBiGRU_model6 = CNNResBiGRU5(shape = (sz - 1, dim))
CNNResBiGRU_model6.compile(optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08), loss='categorical_crossentropy', metrics=['accuracy'])
history6 = CNNResBiGRU_model6.fit(train_raw_ds, validation_data=val_raw_ds, epochs=25, verbose = 1, callbacks = [earlystopping, reduce_lr])
# Out:
# Epoch 1/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 23s 199ms/step - accuracy: 0.1270 - loss: 3.3563 - val_accuracy: 0.4282 - val_loss: 1.9373 - learning_rate: 0.0010
# Epoch 2/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 115ms/step - accuracy: 0.4899 - loss: 1.8049 - val_accuracy: 0.5812 - val_loss: 1.4188 - learning_rate: 0.0010
# Epoch 3/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - accuracy: 0.6132 - loss: 1.3542 - val_accuracy: 0.6164 - val_loss: 1.1829 - learning_rate: 0.0010
# Epoch 4/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 116ms/step - accuracy: 0.6879 - loss: 1.0885 - val_accuracy: 0.6444 - val_loss: 1.0282 - learning_rate: 0.0010
# Epoch 5/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.7732 - loss: 0.8636 - val_accuracy: 0.6997 - val_loss: 0.9005 - learning_rate: 0.0010
# Epoch 6/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 108ms/step - accuracy: 0.8273 - loss: 0.6855 - val_accuracy: 0.6846 - val_loss: 0.8411 - learning_rate: 0.0010
# Epoch 7/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 108ms/step - accuracy: 0.8718 - loss: 0.5440 - val_accuracy: 0.7076 - val_loss: 0.8007 - learning_rate: 0.0010
# Epoch 8/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9000 - loss: 0.4380 - val_accuracy: 0.7450 - val_loss: 0.7115 - learning_rate: 0.0010
# Epoch 9/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 111ms/step - accuracy: 0.9348 - loss: 0.3302 - val_accuracy: 0.7299 - val_loss: 0.7374 - learning_rate: 0.0010
# Epoch 10/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9440 - loss: 0.2780 - val_accuracy: 0.7263 - val_loss: 0.7401 - learning_rate: 0.0010
# Epoch 11/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 114ms/step - accuracy: 0.9585 - loss: 0.2213 - val_accuracy: 0.7148 - val_loss: 0.7633 - learning_rate: 0.0010
# Epoch 12/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - accuracy: 0.9742 - loss: 0.1743 - val_accuracy: 0.7177 - val_loss: 0.7517 - learning_rate: 5.0000e-04
# Epoch 13/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9745 - loss: 0.1602 - val_accuracy: 0.7148 - val_loss: 0.7499 - learning_rate: 5.0000e-04
# Epoch 14/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 112ms/step - accuracy: 0.9804 - loss: 0.1424 - val_accuracy: 0.7148 - val_loss: 0.7754 - learning_rate: 5.0000e-04
# Epoch 15/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 108ms/step - accuracy: 0.9836 - loss: 0.1246 - val_accuracy: 0.7141 - val_loss: 0.7437 - learning_rate: 2.5000e-04

# %%
CNNResBiGRU_results6 = CNNResBiGRU_model6.evaluate(val_raw_ds, batch_size=128)
print("Validation Loss: {}\nValidation Accuracy: {}".format(*CNNResBiGRU_results6))
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6919 - loss: 0.7848
# Validation Loss: 0.7436817288398743
# Validation Accuracy: 0.7140804529190063

# %% [markdown]
# The validation accuracy is lower than with a single convolutional block, indicating that the convolutional block was necessary for feature extraction for the ResBiGRU block.

# %% [markdown]
# #### **Experiment 2.2: 2 preceding convolutional blocks**

# %%
def CNNResBiGRU6(shape):
    block1_input_layer = Input(shape=shape)

    layer = ConvBlock(num_filters = 32, name = "ConvBlock")(block1_input_layer)
    layer = ConvBlock(num_filters = 32, name = "ConvBlock2")(layer)

    # The architecture extensively factors in the gradient vanishing problem.
    layer = ResBiGRU(h1_units = 32, h2_units = 32, name = "ResBiGRU1")(layer)

    layer = GlobalMaxPooling1D()(layer)
    output_layer = Dense(C, activation="softmax")(layer)
    return Model(inputs=block1_input_layer, outputs=output_layer)

# %%
CNNResBiGRU_model7 = CNNResBiGRU6(shape = (sz - 1, dim))
CNNResBiGRU_model7.compile(optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08), loss='categorical_crossentropy', metrics=['accuracy'])
history7 = CNNResBiGRU_model7.fit(train_raw_ds, validation_data=val_raw_ds, epochs=25, verbose = 1)
# Out:
# Epoch 1/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 31s 260ms/step - accuracy: 0.1737 - loss: 3.3602 - val_accuracy: 0.4267 - val_loss: 1.8814
# Epoch 2/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 127ms/step - accuracy: 0.4715 - loss: 1.7292 - val_accuracy: 0.6207 - val_loss: 1.3576
# Epoch 3/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.6030 - loss: 1.2930 - val_accuracy: 0.5876 - val_loss: 1.1713
# Epoch 4/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.6723 - loss: 1.0553 - val_accuracy: 0.6602 - val_loss: 1.0314
# Epoch 5/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 131ms/step - accuracy: 0.7555 - loss: 0.8387 - val_accuracy: 0.6638 - val_loss: 0.9517
# Epoch 6/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.7988 - loss: 0.6940 - val_accuracy: 0.7033 - val_loss: 0.8520
# Epoch 7/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.8455 - loss: 0.5645 - val_accuracy: 0.7162 - val_loss: 0.8302
# Epoch 8/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8656 - loss: 0.4755 - val_accuracy: 0.6954 - val_loss: 0.8482
# Epoch 9/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - accuracy: 0.8981 - loss: 0.3812 - val_accuracy: 0.7234 - val_loss: 0.7688
# Epoch 10/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9109 - loss: 0.3393 - val_accuracy: 0.7744 - val_loss: 0.6364
# Epoch 11/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9357 - loss: 0.2737 - val_accuracy: 0.7335 - val_loss: 0.7406
# Epoch 12/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9423 - loss: 0.2357 - val_accuracy: 0.7328 - val_loss: 0.7551
# Epoch 13/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 0.9555 - loss: 0.2017 - val_accuracy: 0.7636 - val_loss: 0.7551
# Epoch 14/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9609 - loss: 0.1725 - val_accuracy: 0.7392 - val_loss: 0.7524
# Epoch 15/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - accuracy: 0.9602 - loss: 0.1652 - val_accuracy: 0.7586 - val_loss: 0.7678
# Epoch 16/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.9547 - loss: 0.1660 - val_accuracy: 0.7601 - val_loss: 0.7333
# Epoch 17/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9682 - loss: 0.1326 - val_accuracy: 0.7708 - val_loss: 0.7159
# Epoch 18/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9769 - loss: 0.1062 - val_accuracy: 0.7414 - val_loss: 0.7631
# Epoch 19/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 127ms/step - accuracy: 0.9785 - loss: 0.1075 - val_accuracy: 0.7629 - val_loss: 0.7320
# Epoch 20/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9770 - loss: 0.1014 - val_accuracy: 0.7651 - val_loss: 0.7185
# Epoch 21/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9768 - loss: 0.0954 - val_accuracy: 0.7478 - val_loss: 0.7603
# Epoch 22/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.9722 - loss: 0.1109 - val_accuracy: 0.7478 - val_loss: 0.7714
# Epoch 23/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - accuracy: 0.9830 - loss: 0.0784 - val_accuracy: 0.7730 - val_loss: 0.7367
# Epoch 24/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.9849 - loss: 0.0686 - val_accuracy: 0.7672 - val_loss: 0.8025
# Epoch 25/25
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.9787 - loss: 0.0806 - val_accuracy: 0.7795 - val_loss: 0.7063

# %%
CNNResBiGRU_results7_val = CNNResBiGRU_model7.evaluate(val_raw_ds, batch_size=128)
CNNResBiGRU_results7_test = CNNResBiGRU_model7.evaluate(test_raw_ds, batch_size=128)
print("Validation Loss: {}\nValidation Accuracy: {}".format(*CNNResBiGRU_results7_val))
print("Test Loss: {}\nTest Accuracy: {}".format(*CNNResBiGRU_results7_test))
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7586 - loss: 0.7825
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.6812 - loss: 1.1293
# Validation Loss: 0.7063380479812622
# Validation Accuracy: 0.7794540524482727
# Test Loss: 1.1214402914047241
# Test Accuracy: 0.6850618720054626

# %%
predictions7_val = CNNResBiGRU_model7.predict(val_raw_tf, batch_size=128)
predictions7_test = CNNResBiGRU_model7.predict(test_raw_tf, batch_size=128)

predictions7_val =tf.argmax(predictions7_val, axis = 1)
predictions7_test = tf.argmax(predictions7_test, axis = 1)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 225ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step

# %%
# Compare predictions against the targets
print("Validation Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions7_val), sum(np.equal(predictions7_val, y_val))))
print("Test Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions7_test), sum(np.equal(predictions7_test, y_test))))
# Out:
# Validation Data - Total predictions made: 1392. Number of correct predictions: 1085
# Test Data - Total predictions made: 1051. Number of correct predictions: 720

# %% [markdown]
# We can conclude that 2 convolutional blocks beats a single convolutional block.

# %% [markdown]
# ## **Experiment 3: ResBiGRU (raw + differenced time series weighted by Rocket inputs)**

# %% [markdown]
# So far in experiments 1 and 2, we have shown incorporating information from both the raw time series and the differenced time series can improve the classification performance. In this experiment, we want to explore whether the extracted Rocket features might further improve classification performance, and if so, how best to integrate them into the model. We will consider the case where we intgrate both the raw time series and the differenced time series and we will consider the case where we only integrate the raw time series.

# %% [markdown]
# #### **Experiment 3.1: Integrating after GlobalMaxPool layer (raw time series only)**

# %% [markdown]
# An obvious place to integrate the extracted Rocket features, which do not have a time dimension, is after the time dimension is removed from the CNN-ResBiGRU network. The integration can be directly in a concatenation or in a two step process, where the most important Rocket features are extracted in the first step, then merged with the main network in the second step.

# %% [markdown]
# In this experiment, we apply batch normalisation to both the component acting on the raw time series and the component acting on the Rocket.
#
# In a since discarded experiment, we consider concatenating the two components and adding an additional fully connected layer on the combined fields.
#
# In the experiment shown below, we follow up on the Rocket batch normalisation with a fully connected layer of 64 dimensions, in order to condense the 9,996 Rocket features into a more compact representation. This replaced the additional fully connected layer on the combined fields.

# %%
def RocketCNNResBiGRU(ts_raw_shape, pca_raw_shape):
    ts_raw_input = Input(shape=ts_raw_shape, name = "raw")
    pca_raw_input = Input(shape=pca_raw_shape, name = "pca")

    ts_layer = ConvBlock(num_filters = 32, name = "ConvBlock")(ts_raw_input)
    ts_layer = ConvBlock(num_filters = 32, name = "ConvBlock2")(ts_layer)
    ts_layer = ResBiGRU(h1_units = 32, h2_units = 32, name = "ResBiGRU1")(ts_layer)
    ts_layer = GlobalMaxPooling1D()(ts_layer)

    pca_layer = BatchNormalization()(pca_raw_input)
    pca_layer = Dense(64, activation="sigmoid")(pca_layer) # Compress the information into 32 dimensions

    combined_layer = Concatenate(axis = 1)([pca_layer, ts_layer])

    output_layer = Dense(C, activation="softmax")(combined_layer)
    return Model(inputs=[pca_raw_input, ts_raw_input], outputs=output_layer)

# %%
RocketCNNResBiGRU_model = RocketCNNResBiGRU(ts_raw_shape = (sz - 1, dim), pca_raw_shape = (128,))
RocketCNNResBiGRU_model.summary()
# Out:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ raw (InputLayer)          │ (None, 149, 6)         │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ConvBlock (ConvBlock)     │ (None, 149, 32)        │          2,080 │ raw[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pca (InputLayer)          │ (None, 128)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ConvBlock2 (ConvBlock)    │ (None, 149, 32)        │         10,400 │ ConvBlock[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 128)            │            512 │ pca[0][0]              │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ResBiGRU1 (ResBiGRU)      │ (None, 149, 64)        │         25,408 │ ConvBlock2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_14 (Dense)          │ (None, 64)             │          8,256 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling1d_13   │ (None, 64)             │              0 │ ResBiGRU1[0][0]        │
# │ (GlobalMaxPooling1D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 128)            │              0 │ dense_14[0][0],        │
# │ (Concatenate)             │                        │                │ global_max_pooling1d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_15 (Dense)          │ (None, 31)             │          3,999 │ concatenate_4[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 50,655 (197.87 KB)
#  Trainable params: 50,271 (196.37 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
RocketCNNResBiGRU_model = RocketCNNResBiGRU(ts_raw_shape = (sz - 1, dim), pca_raw_shape = (128,))
RocketCNNResBiGRU_model.compile(optimizer=Adam(learning_rate=0.001, beta_1=0.90, beta_2=0.999, epsilon=1e-08), loss='categorical_crossentropy', metrics=['accuracy'])
historyR1 = RocketCNNResBiGRU_model.fit(train_rr_ds, validation_data=val_rr_ds, epochs=50, verbose = 1)
# Out:
# Epoch 1/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 34s 260ms/step - accuracy: 0.2106 - loss: 3.1160 - val_accuracy: 0.5172 - val_loss: 1.7609
# Epoch 2/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 25s 127ms/step - accuracy: 0.6123 - loss: 1.5321 - val_accuracy: 0.6329 - val_loss: 1.2299
# Epoch 3/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.7333 - loss: 1.0348 - val_accuracy: 0.6782 - val_loss: 0.9471
# Epoch 4/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.8143 - loss: 0.7341 - val_accuracy: 0.7112 - val_loss: 0.8359
# Epoch 5/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.8795 - loss: 0.5417 - val_accuracy: 0.7292 - val_loss: 0.7242
# Epoch 6/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.9189 - loss: 0.4026 - val_accuracy: 0.7428 - val_loss: 0.6768
# Epoch 7/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - accuracy: 0.9394 - loss: 0.3157 - val_accuracy: 0.7335 - val_loss: 0.6815
# Epoch 8/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9503 - loss: 0.2649 - val_accuracy: 0.7457 - val_loss: 0.6267
# Epoch 9/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 138ms/step - accuracy: 0.9667 - loss: 0.2071 - val_accuracy: 0.7536 - val_loss: 0.6379
# Epoch 10/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 129ms/step - accuracy: 0.9668 - loss: 0.1841 - val_accuracy: 0.7723 - val_loss: 0.5794
# Epoch 11/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9625 - loss: 0.1661 - val_accuracy: 0.7730 - val_loss: 0.5942
# Epoch 12/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 124ms/step - accuracy: 0.9791 - loss: 0.1277 - val_accuracy: 0.7680 - val_loss: 0.6251
# Epoch 13/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.9730 - loss: 0.1258 - val_accuracy: 0.7493 - val_loss: 0.6413
# Epoch 14/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9813 - loss: 0.1049 - val_accuracy: 0.7450 - val_loss: 0.6074
# Epoch 15/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.9839 - loss: 0.0878 - val_accuracy: 0.7629 - val_loss: 0.6000
# Epoch 16/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - accuracy: 0.9863 - loss: 0.0935 - val_accuracy: 0.7593 - val_loss: 0.5857
# Epoch 17/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9890 - loss: 0.0674 - val_accuracy: 0.7802 - val_loss: 0.5525
# Epoch 18/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.9954 - loss: 0.0575 - val_accuracy: 0.7371 - val_loss: 0.6796
# Epoch 19/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 130ms/step - accuracy: 0.9878 - loss: 0.0655 - val_accuracy: 0.7694 - val_loss: 0.5935
# Epoch 20/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - accuracy: 0.9938 - loss: 0.0498 - val_accuracy: 0.7802 - val_loss: 0.5633
# Epoch 21/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9932 - loss: 0.0463 - val_accuracy: 0.7536 - val_loss: 0.6331
# Epoch 22/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.9960 - loss: 0.0358 - val_accuracy: 0.7550 - val_loss: 0.6329
# Epoch 23/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 129ms/step - accuracy: 0.9942 - loss: 0.0428 - val_accuracy: 0.7550 - val_loss: 0.6099
# Epoch 24/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - accuracy: 0.9934 - loss: 0.0408 - val_accuracy: 0.7644 - val_loss: 0.5981
# Epoch 25/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9963 - loss: 0.0306 - val_accuracy: 0.7507 - val_loss: 0.6446
# Epoch 26/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.9949 - loss: 0.0329 - val_accuracy: 0.7787 - val_loss: 0.6055
# Epoch 27/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 131ms/step - accuracy: 0.9950 - loss: 0.0333 - val_accuracy: 0.7385 - val_loss: 0.7309
# Epoch 28/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9938 - loss: 0.0371 - val_accuracy: 0.7486 - val_loss: 0.6984
# Epoch 29/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - accuracy: 0.9941 - loss: 0.0321 - val_accuracy: 0.7651 - val_loss: 0.6238
# Epoch 30/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - accuracy: 0.9987 - loss: 0.0215 - val_accuracy: 0.7665 - val_loss: 0.6361
# Epoch 31/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - accuracy: 0.9973 - loss: 0.0239 - val_accuracy: 0.7629 - val_loss: 0.6536
# Epoch 32/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9964 - loss: 0.0254 - val_accuracy: 0.7629 - val_loss: 0.6402
# Epoch 33/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.9937 - loss: 0.0278 - val_accuracy: 0.7730 - val_loss: 0.6513
# Epoch 34/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - accuracy: 0.9949 - loss: 0.0236 - val_accuracy: 0.7543 - val_loss: 0.7275
# Epoch 35/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - accuracy: 0.9934 - loss: 0.0276 - val_accuracy: 0.7586 - val_loss: 0.7402
# Epoch 36/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.9929 - loss: 0.0257 - val_accuracy: 0.7622 - val_loss: 0.7051
# Epoch 37/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 144ms/step - accuracy: 0.9991 - loss: 0.0153 - val_accuracy: 0.7716 - val_loss: 0.7069
# Epoch 38/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 155ms/step - accuracy: 0.9991 - loss: 0.0151 - val_accuracy: 0.7780 - val_loss: 0.7086
# Epoch 39/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - accuracy: 0.9947 - loss: 0.0258 - val_accuracy: 0.7759 - val_loss: 0.6464
# Epoch 40/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - accuracy: 0.9998 - loss: 0.0124 - val_accuracy: 0.7716 - val_loss: 0.7001
# Epoch 41/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - accuracy: 0.9989 - loss: 0.0103 - val_accuracy: 0.7730 - val_loss: 0.7207
# Epoch 42/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 138ms/step - accuracy: 0.9985 - loss: 0.0122 - val_accuracy: 0.7608 - val_loss: 0.7543
# Epoch 43/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - accuracy: 0.9975 - loss: 0.0153 - val_accuracy: 0.7450 - val_loss: 0.8038
# Epoch 44/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.9938 - loss: 0.0265 - val_accuracy: 0.7716 - val_loss: 0.7350
# Epoch 45/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.9963 - loss: 0.0213 - val_accuracy: 0.7802 - val_loss: 0.6697
# Epoch 46/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9990 - loss: 0.0133 - val_accuracy: 0.7665 - val_loss: 0.6925
# Epoch 47/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - accuracy: 0.9970 - loss: 0.0133 - val_accuracy: 0.7615 - val_loss: 0.7008
# Epoch 48/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 0.9991 - loss: 0.0119 - val_accuracy: 0.7629 - val_loss: 0.7439
# Epoch 49/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - accuracy: 0.9981 - loss: 0.0138 - val_accuracy: 0.7615 - val_loss: 0.8006
# Epoch 50/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 160ms/step - accuracy: 0.9995 - loss: 0.0101 - val_accuracy: 0.7902 - val_loss: 0.6660

# %%
RocketCNNResBiGRU_results_val = RocketCNNResBiGRU_model.evaluate(val_rr_ds, batch_size=128)
RocketCNNResBiGRU_results_test = RocketCNNResBiGRU_model.evaluate(test_rr_ds, batch_size=128)
print("Validation Loss: {}\nValidation Accuracy: {}".format(*RocketCNNResBiGRU_results_val))
print("Test Loss: {}\nTest Accuracy: {}".format(*RocketCNNResBiGRU_results_test))
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7759 - loss: 0.7295
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.7722 - loss: 0.8387
# Validation Loss: 0.6660051345825195
# Validation Accuracy: 0.790229856967926
# Test Loss: 0.8363613486289978
# Test Accuracy: 0.7621312737464905

# %%
predictions_combined_val = RocketCNNResBiGRU_model.predict((val_pca_tf, val_raw_tf), batch_size=128)
predictions_combined_test = RocketCNNResBiGRU_model.predict((test_pca_tf, test_raw_tf), batch_size=128)

predictions_combined_val =tf.argmax(predictions_combined_val, axis = 1)
predictions_combined_test = tf.argmax(predictions_combined_test, axis = 1)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step

# %%
# Compare predictions against the targets
print("Validation Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions_combined_val), sum(np.equal(predictions_combined_val, y_val))))
print("Test Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions_combined_test), sum(np.equal(predictions_combined_test, y_test))))
# Out:
# Validation Data - Total predictions made: 1392. Number of correct predictions: 1100
# Test Data - Total predictions made: 1051. Number of correct predictions: 801

# %% [markdown]
# This experiment ended in success. The validation accuracy beat the accuracy of the best performing model so far by 1%.

# %% [markdown]
# #### **Experiment 3.2: Breaking experiment 3.1 into a component-wise training process**

# %% [markdown]
# Given experiment 3.1 failed to train, and it was postulated that this was due to the components possibly being in a feedback loop, where improvements in one component resulted in declines in the performance of the second component, we attempt to alternately train the Rocket and CNN-ResBiGRU component, while holding the weights of the alternate component constant, in each epoch.
#
# It was later observed this approach was not effective for training the weights, so the Rocket and CNN-ResBiGRU models were pre-trained separately and the weights copied in to the combined model.

# %% [markdown]
# **Pretrain Rocket PCA model component independently**

# %%
# Note the time series raw input is not used.
ts_raw_input  = Input(shape=(sz - 1, dim), name = "raw")
pca_raw_input = Input(shape=(128,), name = "pca")

layer = BatchNormalization(name = "pca_BatchNorm")(pca_raw_input)
layer = Dense(64, activation="sigmoid", name = "pca_Dense")(layer)
output_layer = Dense(C, activation="softmax")(layer)
pretrained_rocket_model = Model(inputs={"raw": ts_raw_input, "pca": pca_raw_input}, outputs=output_layer)

# %%
pretrained_rocket_model.compile(optimizer=Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999, epsilon=1e-08), loss='categorical_crossentropy', metrics=['accuracy'])
history_pretrained_rocket_model = pretrained_rocket_model.fit(train_rr_ds,  validation_data = val_rr_ds, epochs=50, verbose = 1, callbacks = [earlystopping, reduce_lr])
# Out:
# Epoch 1/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.0602 - loss: 3.4493 - val_accuracy: 0.1473 - val_loss: 3.1214 - learning_rate: 0.0010
# Epoch 2/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2371 - loss: 2.9642 - val_accuracy: 0.3628 - val_loss: 2.7862 - learning_rate: 0.0010
# Epoch 3/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5329 - loss: 2.5565 - val_accuracy: 0.6243 - val_loss: 2.4038 - learning_rate: 0.0010
# Epoch 4/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7419 - loss: 2.1398 - val_accuracy: 0.6947 - val_loss: 2.0105 - learning_rate: 0.0010
# Epoch 5/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7990 - loss: 1.7225 - val_accuracy: 0.7249 - val_loss: 1.6418 - learning_rate: 0.0010
# Epoch 6/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8278 - loss: 1.3565 - val_accuracy: 0.7320 - val_loss: 1.3424 - learning_rate: 0.0010
# Epoch 7/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8490 - loss: 1.0654 - val_accuracy: 0.7392 - val_loss: 1.1192 - learning_rate: 0.0010
# Epoch 8/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8662 - loss: 0.8379 - val_accuracy: 0.7450 - val_loss: 0.9653 - learning_rate: 0.0010
# Epoch 9/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8946 - loss: 0.6807 - val_accuracy: 0.7550 - val_loss: 0.8619 - learning_rate: 0.0010
# Epoch 10/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9096 - loss: 0.5634 - val_accuracy: 0.7493 - val_loss: 0.7952 - learning_rate: 0.0010
# Epoch 11/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9291 - loss: 0.4812 - val_accuracy: 0.7529 - val_loss: 0.7492 - learning_rate: 0.0010
# Epoch 12/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9332 - loss: 0.4214 - val_accuracy: 0.7557 - val_loss: 0.7169 - learning_rate: 0.0010
# Epoch 13/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9416 - loss: 0.3695 - val_accuracy: 0.7557 - val_loss: 0.6943 - learning_rate: 0.0010
# Epoch 14/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9484 - loss: 0.3325 - val_accuracy: 0.7593 - val_loss: 0.6757 - learning_rate: 0.0010
# Epoch 15/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9536 - loss: 0.3037 - val_accuracy: 0.7636 - val_loss: 0.6629 - learning_rate: 0.0010
# Epoch 16/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9618 - loss: 0.2683 - val_accuracy: 0.7601 - val_loss: 0.6533 - learning_rate: 0.0010
# Epoch 17/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9598 - loss: 0.2550 - val_accuracy: 0.7608 - val_loss: 0.6471 - learning_rate: 0.0010
# Epoch 18/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9679 - loss: 0.2303 - val_accuracy: 0.7629 - val_loss: 0.6432 - learning_rate: 0.0010
# Epoch 19/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9705 - loss: 0.2114 - val_accuracy: 0.7593 - val_loss: 0.6368 - learning_rate: 0.0010
# Epoch 20/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9732 - loss: 0.2036 - val_accuracy: 0.7615 - val_loss: 0.6334 - learning_rate: 0.0010
# Epoch 21/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9806 - loss: 0.1796 - val_accuracy: 0.7622 - val_loss: 0.6316 - learning_rate: 0.0010
# Epoch 22/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9809 - loss: 0.1686 - val_accuracy: 0.7615 - val_loss: 0.6285 - learning_rate: 0.0010
# Epoch 23/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9815 - loss: 0.1589 - val_accuracy: 0.7615 - val_loss: 0.6295 - learning_rate: 0.0010
# Epoch 24/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9838 - loss: 0.1473 - val_accuracy: 0.7622 - val_loss: 0.6304 - learning_rate: 0.0010
# Epoch 25/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9870 - loss: 0.1374 - val_accuracy: 0.7622 - val_loss: 0.6297 - learning_rate: 0.0010
# Epoch 26/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9894 - loss: 0.1329 - val_accuracy: 0.7608 - val_loss: 0.6304 - learning_rate: 5.0000e-04
# Epoch 27/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9845 - loss: 0.1310 - val_accuracy: 0.7622 - val_loss: 0.6313 - learning_rate: 5.0000e-04
# Epoch 28/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9876 - loss: 0.1233 - val_accuracy: 0.7608 - val_loss: 0.6330 - learning_rate: 5.0000e-04
# Epoch 29/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9872 - loss: 0.1198 - val_accuracy: 0.7593 - val_loss: 0.6334 - learning_rate: 2.5000e-04
# Epoch 30/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.1143 - val_accuracy: 0.7601 - val_loss: 0.6328 - learning_rate: 2.5000e-04

# %%
pretrained_rocket_model.save('../models/BlockRocketExperiments/pretrained_rocket_model.keras')
with open('../models/BlockRocketExperiments/history_pretrained_rocket_model.pkl', 'wb') as f:
    pickle.dump(history_pretrained_rocket_model.history, f)

# %%
# Load the model
pretrained_rocket_model = load_model('../models/BlockRocketExperiments/pretrained_rocket_model.keras')

# Load the training history
with open('../models/BlockRocketExperiments/history_pretrained_rocket_model.pkl', 'rb') as f:
    history_pretrained_rocket_model = pickle.load(f)

# %%
pretrained_rocket_results_val = pretrained_rocket_model.evaluate(val_rr_ds, batch_size=128)
pretrained_rocket_results_test = pretrained_rocket_model.evaluate(test_rr_ds, batch_size=128)
print("Validation Loss: {}\nValidation Accuracy: {}".format(*pretrained_rocket_results_val))
print("Test Loss: {}\nTest Accuracy: {}".format(*pretrained_rocket_results_test))
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7521 - loss: 0.6616
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7294 - loss: 0.9097
# Validation Loss: 0.6328442692756653
# Validation Accuracy: 0.7600574493408203
# Test Loss: 0.885633111000061
# Test Accuracy: 0.7288296818733215

# %%
predictions_pretrained_rocket_val = pretrained_rocket_model.predict((val_pca_tf, val_raw_tf), batch_size=128)
predictions_pretrained_rocket_test = pretrained_rocket_model.predict((test_pca_tf, test_raw_tf), batch_size=128)

predictions_pretrained_rocket_val =tf.argmax(predictions_pretrained_rocket_val, axis = 1)
predictions_pretrained_rocket_test = tf.argmax(predictions_pretrained_rocket_test, axis = 1)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
# Compare predictions against the targets
print("Validation Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions_pretrained_rocket_val), sum(np.equal(predictions_pretrained_rocket_val, y_val))))
print("Test Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions_pretrained_rocket_test), sum(np.equal(predictions_pretrained_rocket_test, y_test))))
# Out:
# Validation Data - Total predictions made: 1392. Number of correct predictions: 1058
# Test Data - Total predictions made: 1051. Number of correct predictions: 766

# %% [markdown]
# **Pretrain CNN-ResBiGRU model component independently**

# %%
# Note the PCA raw input is not used.
ts_raw_input  = Input(shape=(sz - 1, dim), name = "raw")

layer = ConvBlock(num_filters = 32, name = "ts_ConvBlock")(ts_raw_input)
layer = ConvBlock(num_filters = 32, name = "ts_ConvBlock2")(layer)
layer = ResBiGRU(h1_units =32, h2_units = 32, name = "ts_ResBiGRU1")(layer)
layer = GlobalMaxPooling1D(name = "ts_GlobalMaxPooling")(layer)
layer = BatchNormalization(name = "ts_BatchNorm")(layer)
output_layer = Dense(C, activation="softmax")(layer)
pretrained_cnnresbigru_model = Model(inputs=ts_raw_input, outputs = output_layer)

# %%
pretrained_cnnresbigru_model.compile(optimizer=Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999, epsilon=1e-08), loss='categorical_crossentropy', metrics=['accuracy'])
history_cnnresbigru_model = pretrained_cnnresbigru_model.fit(train_raw_ds,  validation_data = val_raw_ds, epochs=50, verbose = 1, callbacks = [earlystopping, reduce_lr])
# Out:
# Epoch 1/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 32s 269ms/step - accuracy: 0.2318 - loss: 2.6390 - val_accuracy: 0.4375 - val_loss: 1.8288 - learning_rate: 0.0010
# Epoch 2/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - accuracy: 0.5558 - loss: 1.5121 - val_accuracy: 0.5575 - val_loss: 1.2772 - learning_rate: 0.0010
# Epoch 3/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - accuracy: 0.6747 - loss: 1.1204 - val_accuracy: 0.6415 - val_loss: 1.0672 - learning_rate: 0.0010
# Epoch 4/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.7580 - loss: 0.8714 - val_accuracy: 0.6825 - val_loss: 0.9069 - learning_rate: 0.0010
# Epoch 5/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.8202 - loss: 0.6894 - val_accuracy: 0.6911 - val_loss: 0.8284 - learning_rate: 0.0010
# Epoch 6/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.8398 - loss: 0.5780 - val_accuracy: 0.7184 - val_loss: 0.7905 - learning_rate: 0.0010
# Epoch 7/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - accuracy: 0.8865 - loss: 0.4520 - val_accuracy: 0.7112 - val_loss: 0.7850 - learning_rate: 0.0010
# Epoch 8/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.8956 - loss: 0.3870 - val_accuracy: 0.7155 - val_loss: 0.7661 - learning_rate: 0.0010
# Epoch 9/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - accuracy: 0.9216 - loss: 0.3131 - val_accuracy: 0.7407 - val_loss: 0.6974 - learning_rate: 0.0010
# Epoch 10/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.9472 - loss: 0.2330 - val_accuracy: 0.7364 - val_loss: 0.7000 - learning_rate: 0.0010
# Epoch 11/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 127ms/step - accuracy: 0.9569 - loss: 0.1969 - val_accuracy: 0.7292 - val_loss: 0.7330 - learning_rate: 0.0010
# Epoch 12/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9659 - loss: 0.1647 - val_accuracy: 0.7435 - val_loss: 0.6846 - learning_rate: 0.0010
# Epoch 13/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9701 - loss: 0.1418 - val_accuracy: 0.7320 - val_loss: 0.7349 - learning_rate: 0.0010
# Epoch 14/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.9791 - loss: 0.1200 - val_accuracy: 0.7105 - val_loss: 0.7848 - learning_rate: 0.0010
# Epoch 15/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.9832 - loss: 0.1058 - val_accuracy: 0.7428 - val_loss: 0.6879 - learning_rate: 0.0010

# %%
pretrained_cnnresbigru_model.save('../models/BlockRocketExperiments/pretrained_cnnresbigru_model.keras')
with open('../models/BlockRocketExperiments/history_cnnresbigru_model.pkl', 'wb') as f:
    pickle.dump(history_cnnresbigru_model.history, f)

# %%
# Load the model
custom_objects = {'ConvBlock': ConvBlock, 'ResBiGRU': ResBiGRU}
pretrained_cnnresbigru_model = load_model('../models/BlockRocketExperiments/pretrained_cnnresbigru_model.keras', custom_objects=custom_objects)

# Load the training history
with open('../models/BlockRocketExperiments/history_cnnresbigru_model.pkl', 'rb') as f:
    history_cnnresbigru_model = pickle.load(f)

# %%
pretrained_cnnresbigru_results_val = pretrained_cnnresbigru_model.evaluate(val_raw_ds, batch_size=128)
pretrained_cnnresbigru_results_test = pretrained_cnnresbigru_model.evaluate(test_raw_ds, batch_size=128)
print("Validation Loss: {}\nValidation Accuracy: {}".format(*pretrained_cnnresbigru_results_val))
print("Test Loss: {}\nTest Accuracy: {}".format(*pretrained_cnnresbigru_results_test))
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.7338 - loss: 0.7156
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.7282 - loss: 1.0129
# Validation Loss: 0.6878427863121033
# Validation Accuracy: 0.7428160905838013
# Test Loss: 0.9957500696182251
# Test Accuracy: 0.7269267439842224

# %%
predictions_pretrained_cnnresbigru_val = pretrained_cnnresbigru_model.predict(val_raw_tf, batch_size=128)
predictions_pretrained_cnnresbigru_test = pretrained_cnnresbigru_model.predict(test_raw_tf, batch_size=128)

predictions_pretrained_cnnresbigru_val =tf.argmax(predictions_pretrained_cnnresbigru_val, axis = 1)
predictions_pretrained_cnnresbigru_test = tf.argmax(predictions_pretrained_cnnresbigru_test, axis = 1)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step

# %%
# Compare predictions against the targets
print("Validation Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions_pretrained_cnnresbigru_val), sum(np.equal(predictions_pretrained_cnnresbigru_val, y_val))))
print("Test Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions_pretrained_cnnresbigru_test), sum(np.equal(predictions_pretrained_cnnresbigru_test, y_test))))
# Out:
# Validation Data - Total predictions made: 1392. Number of correct predictions: 1034
# Test Data - Total predictions made: 1051. Number of correct predictions: 764

# %% [markdown]
# **Define combined model**

# %%
ts_raw_input = Input(shape=(sz - 1, dim), name = "raw")
pca_raw_input = Input(shape=(128,), name = "pca")

# Define the layers of the time series model
ts_layer = ConvBlock(num_filters = 32, name = "ts_ConvBlock1")(ts_raw_input)
ts_layer = ConvBlock(num_filters = 32, name = "ts_ConvBlock2")(ts_layer)
ts_layer = ResBiGRU(h1_units = 32, h2_units = 32, name = "ts_ResBiGRU1")(ts_layer)
ts_layer = GlobalMaxPooling1D(name = "ts_GlobalMaxPooling")(ts_layer)
ts_layer = BatchNormalization(momentum=0.99, center=True, scale=True, name = "ts_BatchNorm")(ts_layer)
output_ts = ts_layer

# Define the layers of the PCA model based on the Rocket features
pca_layer = BatchNormalization(name = "pca_BatchNorm")(pca_raw_input)
pca_layer = Dense(64, activation="sigmoid", name = "pca_Dense")(pca_layer)
output_pca = pca_layer

# Define the two component models
ts_model = Model(inputs=ts_raw_input, outputs=output_ts)
pca_model = Model(inputs=pca_raw_input, outputs=output_pca)

# Define the layers of the combined model
combined_layer = Concatenate(axis = 1)([ts_model.output, pca_model.output])
#combined_layer = Dense(32, activation="sigmoid", name = "comb_Dense1")(combined_layer) # Compress the information into 32 dimensions
final_output  = Dense(C, activation="softmax", name = "comb_Dense2")(combined_layer)

# Define the combined model
combined_model = Model(inputs= {"raw": ts_model.input, "pca": pca_model.input}, outputs = final_output)
combined_model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ raw (InputLayer)          │ (None, 149, 6)         │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_ConvBlock1 (ConvBlock) │ (None, 149, 32)        │          2,080 │ raw[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_ConvBlock2 (ConvBlock) │ (None, 149, 32)        │         10,400 │ ts_ConvBlock1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_ResBiGRU1 (ResBiGRU)   │ (None, 149, 64)        │         25,408 │ ts_ConvBlock2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pca (InputLayer)          │ (None, 128)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_GlobalMaxPooling       │ (None, 64)             │              0 │ ts_ResBiGRU1[0][0]     │
# │ (GlobalMaxPooling1D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pca_BatchNorm             │ (None, 128)            │            512 │ pca[0][0]              │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_BatchNorm              │ (None, 64)             │            256 │ ts_GlobalMaxPooling[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pca_Dense (Dense)         │ (None, 64)             │          8,256 │ pca_BatchNorm[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 128)            │              0 │ ts_BatchNorm[0][0],    │
# │                           │                        │                │ pca_Dense[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ comb_Dense2 (Dense)       │ (None, 31)             │          3,999 │ concatenate[0][0]      │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 50,911 (198.87 KB)
#  Trainable params: 50,399 (196.87 KB)
#  Non-trainable params: 512 (2.00 KB)

# %%
def copy_model_weights(source, target, mapping):
    # Copy weights from source model to target model based on layer names
    for source_layer_name, target_layer_name in mapping.items():
        try:
            target.get_layer(name=target_layer_name).set_weights(
                source.get_layer(name=source_layer_name).get_weights()
            )
            print(f"Copied weights from {source_layer_name} to {target_layer_name}")
        except Exception as e:
            print(f"Could not copy weights from {source_layer_name} to {target_layer_name}: {e}")
    return target

# %%
rocket_layer_mapping = {
    'pca_Dense': 'pca_Dense',
    'pca_BatchNorm': 'pca_BatchNorm'
}

ts_layer_mapping = {
    'ts_ConvBlock1': 'ts_ConvBlock1',
    'ts_ConvBlock2': 'ts_ConvBlock2',
    'ts_ResBiGRU1': 'ts_ResBiGRU1',
    'ts_GlobalMaxPooling': 'ts_GlobalMaxPooling',
    'ts_BatchNorm': 'ts_BatchNorm'
}

# %% [markdown]
# #### **3.2.1: Using custom train steps**

# %%
combined_model_custom = Model(inputs= {"raw": ts_model.input, "pca": pca_model.input}, outputs = final_output)

combined_model_custom = copy_model_weights(source = pretrained_rocket_model, target = combined_model_custom, mapping = rocket_layer_mapping)
combined_model_custom = copy_model_weights(source = pretrained_cnnresbigru_model, target = combined_model_custom, mapping = ts_layer_mapping)
# Out:
# Copied weights from pca_Dense to pca_Dense
# Copied weights from pca_BatchNorm to pca_BatchNorm
# Could not copy weights from ts_ConvBlock1 to ts_ConvBlock1: No such layer: ts_ConvBlock1. Existing layers are: ['raw', 'ts_ConvBlock', 'ts_ConvBlock2', 'ts_ResBiGRU1', 'ts_GlobalMaxPooling', 'ts_BatchNorm', 'dense_22'].
# Copied weights from ts_ConvBlock2 to ts_ConvBlock2
# Copied weights from ts_ResBiGRU1 to ts_ResBiGRU1
# Copied weights from ts_GlobalMaxPooling to ts_GlobalMaxPooling
# Copied weights from ts_BatchNorm to ts_BatchNorm

# %% [markdown]
# Define the train step for the PCA component. Notice the CNN-ResBiGRU component is held constant.

# %%
@tf.function
def train_step_pca(loss_fn, opt, train_batch):
    """
    This function performs the train step for the PCA component.
    """
    inputs, y_true = train_batch
    input_ResBiGRU, input_pca = inputs["raw"], inputs["pca"]

    with tf.GradientTape() as tape:
        output_pca = pca_model(input_pca, training = True)
        output_resbigru = ts_model(input_ResBiGRU, training = False)
        y_pred = combined_model({"raw": input_ResBiGRU, "pca": input_pca}, training=True)
        loss = loss_fn(y_true, y_pred)

    grads = tape.gradient(loss, pca_model.trainable_weights)
    opt.apply_gradients(zip(grads, pca_model.trainable_weights))

    return loss, y_true, y_pred

# %% [markdown]
# Define the train step for the CNN-ResBiGRU component. Notice the PCA component is held constant.

# %%
@tf.function
def train_step_CNNResBiGRU(loss_fn, opt, train_batch):
    """
    This function performs the train step for the CNN-ResBiGRU component.
    """
    inputs, y_true = train_batch
    input_ResBiGRU, input_pca = inputs["raw"], inputs["pca"]

    with tf.GradientTape() as tape:
        output_pca = pca_model(input_pca, training = False)
        output_resbigru = ts_model(input_ResBiGRU, training = True)
        y_pred = combined_model({"raw": input_ResBiGRU, "pca": input_pca}, training=True)
        loss = loss_fn(y_true, y_pred)

    grads = tape.gradient(loss, pca_model.trainable_weights)
    opt.apply_gradients(zip(grads, pca_model.trainable_weights))

    return loss, y_true, y_pred

# %%
# Define the loss and accuracy metrics and optimizer

loss_metric = tf.keras.metrics.Mean()
accuracy_metric = tf.keras.metrics.CategoricalAccuracy()

# %%
def train_model(loss_fn, training_dataset, epochs, accuracy_metric=accuracy_metric):
    """
    This function should run the custom training loop as described above.
    The function should return a tuple of two lists with the loss and accuracy scores.
    """
    epoch_losses = []
    epoch_acc = []

    pca_opt = Adam(learning_rate=1.0, beta_1=0.99, beta_2=0.999, epsilon=1e-08)
    resbigru_opt = Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999, epsilon=1e-08)

    for epoch in range(epochs):
        loss_metric.reset_state()
        accuracy_metric.reset_state()

        for train_batch in training_dataset:
            # Losses, targets and predicted values after running PCA component
            loss1, y_true1, y_pred1 = train_step_pca(loss_fn, pca_opt, train_batch)

            # Losses, targets and predicted values after running CNN-ResBiGRU component
            loss2, y_true2, y_pred2 = train_step_CNNResBiGRU(loss_fn, resbigru_opt, train_batch)

            # The accuracy and loss metrics are updated after both training steps have been executed
            loss_metric.update_state(loss2)
            accuracy_metric.update_state(y_true2, y_pred2)

        avg_epoch_loss = float(loss_metric.result().numpy())
        avg_epoch_acc = float(accuracy_metric.result().numpy())
        epoch_losses.append(avg_epoch_loss)
        epoch_acc.append(avg_epoch_acc)
        print(f"Epoch {epoch}: loss - {avg_epoch_loss:.4f}, accuracy = {avg_epoch_acc:.4f}")

    return epoch_losses, epoch_acc

# %%
# Run the custom training loop
epoch_losses, epoch_acc = train_model(loss_fn=CategoricalCrossentropy(from_logits = False),
                                      training_dataset=train_rr_ds,
                                      epochs=50)

# %% [markdown]
# This approach was too slow.

# %% [markdown]
# #### **3.2.2: Using Keras (2 x Alternate Training)**

# %%
combined_model = Model(inputs= {"raw": ts_model.input, "pca": pca_model.input}, outputs = final_output)

combined_model = copy_model_weights(source = pretrained_rocket_model, target = combined_model, mapping = rocket_layer_mapping)
combined_model = copy_model_weights(source = pretrained_cnnresbigru_model, target = combined_model, mapping = ts_layer_mapping)

optimiser = Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999, epsilon=1e-08, clipnorm=1.0)
combined_model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Copied weights from pca_Dense to pca_Dense
# Copied weights from pca_BatchNorm to pca_BatchNorm
# Could not copy weights from ts_ConvBlock1 to ts_ConvBlock1: No such layer: ts_ConvBlock1. Existing layers are: ['raw', 'ts_ConvBlock', 'ts_ConvBlock2', 'ts_ResBiGRU1', 'ts_GlobalMaxPooling', 'ts_BatchNorm', 'dense_22'].
# Copied weights from ts_ConvBlock2 to ts_ConvBlock2
# Copied weights from ts_ResBiGRU1 to ts_ResBiGRU1
# Copied weights from ts_GlobalMaxPooling to ts_GlobalMaxPooling
# Copied weights from ts_BatchNorm to ts_BatchNorm

# %%
pca_layers = [layer.name for layer in pca_model.layers]
ts_layers = [layer.name for layer in ts_model.layers]
combined_layers = [layer.name for layer in combined_model.layers]

# The layers which are shared between both components of the model.
shared_layers = list(set(combined_layers) - set(pca_layers) - set(ts_layers))

pca_component_layers = pca_layers + shared_layers
ts_component_layers = ts_layers + shared_layers

# %%
# Custom training loop
epochs = 10 # 5 sub-epochs per parent epoch = 50 epochs

# Keras optimisers are tied to the weights they are created with
ts_optimiser = Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999, epsilon=1e-08)
pca_optimiser = Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999, epsilon=1e-08)

for epoch in range(epochs):
    print(f'Epoch {epoch+1}/{epochs}')

    # Freeze the PCA component and train the CNN-ResBiGRU component
    for layer in combined_model.layers:  # Adjust indices based on your model's architecture
        if layer.name in ts_component_layers:
            layer.trainable = True
        else:
            layer.trainable = False

    combined_model.compile(optimizer= ts_optimiser, loss='categorical_crossentropy', metrics=['accuracy'])
    combined_model.fit(train_rr_ds, validation_data = val_rr_ds, epochs=5, verbose=1)

    # Freeze the CNN-ResBiGRU component and train the PCA component
    for layer in combined_model.layers:  # Adjust indices based on your model's architecture
        if layer.name in pca_component_layers:
            layer.trainable = True
        else:
            layer.trainable = False

    combined_model.compile(optimizer= pca_optimiser, loss='categorical_crossentropy', metrics=['accuracy'])
    combined_model.fit(train_rr_ds, validation_data = val_rr_ds, epochs=5, verbose=1)
# Out:
# Epoch 1/10
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 34s 266ms/step - accuracy: 0.2060 - loss: 2.9261 - val_accuracy: 0.3470 - val_loss: 1.8583
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.5175 - loss: 1.4477 - val_accuracy: 0.5374 - val_loss: 1.2445
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.6585 - loss: 1.0346 - val_accuracy: 0.6329 - val_loss: 0.9865
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.7548 - loss: 0.8013 - val_accuracy: 0.6861 - val_loss: 0.8761
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.8206 - loss: 0.6316 - val_accuracy: 0.6875 - val_loss: 0.8498
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - accuracy: 0.8752 - loss: 0.4775 - val_accuracy: 0.7011 - val_loss: 0.7894
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9065 - loss: 0.3879 - val_accuracy: 0.7126 - val_loss: 0.7458
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9290 - loss: 0.3102 - val_accuracy: 0.7263 - val_loss: 0.7174
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9407 - loss: 0.2765 - val_accuracy: 0.7277 - val_loss: 0.6991
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9521 - loss: 0.2323 - val_accuracy: 0.7299 - val_loss: 0.6936
# Epoch 2/10
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 28s 235ms/step - accuracy: 0.9386 - loss: 0.2473 - val_accuracy: 0.7313 - val_loss: 0.6697
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9454 - loss: 0.2062 - val_accuracy: 0.7249 - val_loss: 0.6738
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9658 - loss: 0.1652 - val_accuracy: 0.7184 - val_loss: 0.7062
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9716 - loss: 0.1427 - val_accuracy: 0.7170 - val_loss: 0.7007
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9773 - loss: 0.1221 - val_accuracy: 0.7263 - val_loss: 0.7117
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9871 - loss: 0.0878 - val_accuracy: 0.7270 - val_loss: 0.6862
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9870 - loss: 0.0775 - val_accuracy: 0.7277 - val_loss: 0.6842
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9915 - loss: 0.0704 - val_accuracy: 0.7256 - val_loss: 0.6950
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9914 - loss: 0.0628 - val_accuracy: 0.7277 - val_loss: 0.7032
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9940 - loss: 0.0583 - val_accuracy: 0.7299 - val_loss: 0.7057
# Epoch 3/10
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 237ms/step - accuracy: 0.9840 - loss: 0.0754 - val_accuracy: 0.7342 - val_loss: 0.7352
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9876 - loss: 0.0665 - val_accuracy: 0.7299 - val_loss: 0.7263
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.9900 - loss: 0.0618 - val_accuracy: 0.7213 - val_loss: 0.8105
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9888 - loss: 0.0619 - val_accuracy: 0.7328 - val_loss: 0.7453
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9902 - loss: 0.0583 - val_accuracy: 0.7349 - val_loss: 0.7110
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.9971 - loss: 0.0390 - val_accuracy: 0.7342 - val_loss: 0.7227
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9965 - loss: 0.0329 - val_accuracy: 0.7263 - val_loss: 0.7664
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9968 - loss: 0.0283 - val_accuracy: 0.7256 - val_loss: 0.7868
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9990 - loss: 0.0254 - val_accuracy: 0.7241 - val_loss: 0.7905
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9985 - loss: 0.0260 - val_accuracy: 0.7277 - val_loss: 0.7878
# Epoch 4/10
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 238ms/step - accuracy: 0.9952 - loss: 0.0378 - val_accuracy: 0.7256 - val_loss: 0.8144
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9937 - loss: 0.0363 - val_accuracy: 0.7148 - val_loss: 0.8688
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9960 - loss: 0.0363 - val_accuracy: 0.7220 - val_loss: 0.8286
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9943 - loss: 0.0330 - val_accuracy: 0.7270 - val_loss: 0.8179
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9924 - loss: 0.0352 - val_accuracy: 0.7320 - val_loss: 0.8537
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9985 - loss: 0.0182 - val_accuracy: 0.7342 - val_loss: 0.8423
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9996 - loss: 0.0169 - val_accuracy: 0.7292 - val_loss: 0.8296
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9998 - loss: 0.0141 - val_accuracy: 0.7241 - val_loss: 0.8344
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9997 - loss: 0.0148 - val_accuracy: 0.7191 - val_loss: 0.8482
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9999 - loss: 0.0120 - val_accuracy: 0.7205 - val_loss: 0.8507
# Epoch 5/10
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 28s 248ms/step - accuracy: 0.9975 - loss: 0.0219 - val_accuracy: 0.7364 - val_loss: 0.8585
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9979 - loss: 0.0223 - val_accuracy: 0.7234 - val_loss: 0.8720
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9965 - loss: 0.0223 - val_accuracy: 0.7213 - val_loss: 0.8938
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9948 - loss: 0.0248 - val_accuracy: 0.7205 - val_loss: 0.9298
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9965 - loss: 0.0191 - val_accuracy: 0.7263 - val_loss: 0.8679
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 103ms/step - accuracy: 0.9994 - loss: 0.0110 - val_accuracy: 0.7284 - val_loss: 0.8316
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9989 - loss: 0.0098 - val_accuracy: 0.7249 - val_loss: 0.8154
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9991 - loss: 0.0107 - val_accuracy: 0.7249 - val_loss: 0.8217
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.7306 - val_loss: 0.8285
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.7306 - val_loss: 0.8266
# Epoch 6/10
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 28s 241ms/step - accuracy: 0.9984 - loss: 0.0165 - val_accuracy: 0.7529 - val_loss: 0.7683
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9959 - loss: 0.0215 - val_accuracy: 0.7198 - val_loss: 0.8457
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9980 - loss: 0.0161 - val_accuracy: 0.7342 - val_loss: 0.8406
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9977 - loss: 0.0162 - val_accuracy: 0.7593 - val_loss: 0.7324
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9983 - loss: 0.0140 - val_accuracy: 0.7284 - val_loss: 0.8743
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - accuracy: 0.9983 - loss: 0.0087 - val_accuracy: 0.7335 - val_loss: 0.8560
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.7378 - val_loss: 0.8431
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.7399 - val_loss: 0.8381
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.7392 - val_loss: 0.8368
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.7349 - val_loss: 0.8444
# Epoch 7/10
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 28s 240ms/step - accuracy: 0.9972 - loss: 0.0133 - val_accuracy: 0.7335 - val_loss: 0.8559
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9990 - loss: 0.0113 - val_accuracy: 0.7421 - val_loss: 0.8487
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9990 - loss: 0.0143 - val_accuracy: 0.7270 - val_loss: 0.9092
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9977 - loss: 0.0128 - val_accuracy: 0.7407 - val_loss: 0.9110
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9992 - loss: 0.0103 - val_accuracy: 0.7414 - val_loss: 0.8125
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 15s 99ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.7428 - val_loss: 0.8343
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.7421 - val_loss: 0.8615
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.7407 - val_loss: 0.8715
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.7457 - val_loss: 0.8641
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.7478 - val_loss: 0.8658
# Epoch 8/10
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 28s 239ms/step - accuracy: 0.9998 - loss: 0.0063 - val_accuracy: 0.7493 - val_loss: 0.8568
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9999 - loss: 0.0069 - val_accuracy: 0.7320 - val_loss: 0.9364
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9993 - loss: 0.0073 - val_accuracy: 0.7493 - val_loss: 0.8406
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9995 - loss: 0.0083 - val_accuracy: 0.7313 - val_loss: 0.9505
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9993 - loss: 0.0065 - val_accuracy: 0.7507 - val_loss: 0.7823
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9998 - loss: 0.0048 - val_accuracy: 0.7478 - val_loss: 0.7955
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.7514 - val_loss: 0.8243
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.7522 - val_loss: 0.8449
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.7522 - val_loss: 0.8534
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.7507 - val_loss: 0.8494
# Epoch 9/10
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.9999 - loss: 0.0062 - val_accuracy: 0.7306 - val_loss: 0.9530
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9987 - loss: 0.0093 - val_accuracy: 0.7507 - val_loss: 0.8659
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9988 - loss: 0.0103 - val_accuracy: 0.7471 - val_loss: 0.8926
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9965 - loss: 0.0113 - val_accuracy: 0.7486 - val_loss: 0.9651
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9982 - loss: 0.0127 - val_accuracy: 0.7536 - val_loss: 0.9418
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9979 - loss: 0.0086 - val_accuracy: 0.7522 - val_loss: 0.8825
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.7493 - val_loss: 0.8582
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.7543 - val_loss: 0.8732
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.7536 - val_loss: 0.8882
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.7565 - val_loss: 0.8919
# Epoch 10/10
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 28s 238ms/step - accuracy: 0.9987 - loss: 0.0076 - val_accuracy: 0.7421 - val_loss: 0.9305
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9996 - loss: 0.0078 - val_accuracy: 0.7435 - val_loss: 0.8751
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9980 - loss: 0.0084 - val_accuracy: 0.7378 - val_loss: 0.9393
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9986 - loss: 0.0080 - val_accuracy: 0.7364 - val_loss: 0.9710
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9996 - loss: 0.0058 - val_accuracy: 0.7493 - val_loss: 0.9434
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 15s 97ms/step - accuracy: 0.9998 - loss: 0.0039 - val_accuracy: 0.7486 - val_loss: 0.9253
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9998 - loss: 0.0033 - val_accuracy: 0.7435 - val_loss: 0.9266
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.7421 - val_loss: 0.9494
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7457 - val_loss: 0.9547
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.7493 - val_loss: 0.9363

# %%
combined_results_val = combined_model.evaluate(val_rr_ds, batch_size=128)
combined_results_test = combined_model.evaluate(test_rr_ds, batch_size=128)
print("Validation Loss: {}\nValidation Accuracy: {}".format(*combined_results_val))
print("Test Loss: {}\nTest Accuracy: {}".format(*combined_results_test))
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7532 - loss: 1.2090
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.7555 - loss: 1.1266
# Validation Loss: 1.1175472736358643
# Validation Accuracy: 0.7629310488700867
# Test Loss: 1.1137651205062866
# Test Accuracy: 0.7526165843009949

# %%
predictions_combined_val = combined_model.predict((val_pca_tf, val_raw_tf), batch_size=128)
predictions_combined_test = combined_model.predict((test_pca_tf, test_raw_tf), batch_size=128)

predictions_combined_val =tf.argmax(predictions_combined_val, axis = 1)
predictions_combined_test = tf.argmax(predictions_combined_test, axis = 1)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step

# %%
# Compare predictions against the targets
print("Validation Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions_combined_val), sum(np.equal(predictions_combined_val, y_val))))
print("Test Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions_combined_test), sum(np.equal(predictions_combined_test, y_test))))
# Out:
# Validation Data - Total predictions made: 1392. Number of correct predictions: 1062
# Test Data - Total predictions made: 1051. Number of correct predictions: 791

# %%
pretrained_cnnresbigru_model.save('../models/BlockRocketExperiments/combined_model1.keras')

# %%
# Load the model
custom_objects = {'ConvBlock': ConvBlock, 'ResBiGRU': ResBiGRU}
pretrained_cnnresbigru_model = load_model('../models/BlockRocketExperiments/combined_model1.keras', custom_objects=custom_objects)

# %% [markdown]
# Alternately training each component does not appear to be the right approach. Can they both be trained concurrently after the pretraining?

# %% [markdown]
# **3.2.3: Keras (3 x alternate pretraining)**

# %%
combined_model2 = Model(inputs= {"raw": ts_model.input, "pca": pca_model.input}, outputs = final_output)

combined_model2 = copy_model_weights(source = pretrained_rocket_model, target = combined_model2, mapping = rocket_layer_mapping)
combined_model2 = copy_model_weights(source = pretrained_cnnresbigru_model, target = combined_model2, mapping = ts_layer_mapping)
# Out:
# Copied weights from pca_Dense to pca_Dense
# Copied weights from pca_BatchNorm to pca_BatchNorm
# Could not copy weights from ts_ConvBlock1 to ts_ConvBlock1: No such layer: ts_ConvBlock1. Existing layers are: ['raw', 'ts_ConvBlock', 'ts_ConvBlock2', 'ts_ResBiGRU1', 'ts_GlobalMaxPooling', 'ts_BatchNorm', 'dense_22'].
# Copied weights from ts_ConvBlock2 to ts_ConvBlock2
# Copied weights from ts_ResBiGRU1 to ts_ResBiGRU1
# Copied weights from ts_GlobalMaxPooling to ts_GlobalMaxPooling
# Copied weights from ts_BatchNorm to ts_BatchNorm

# %%
optimiser2 = Adam(learning_rate=1.0, beta_1=0.99, beta_2=0.999, epsilon=1e-08, clipnorm=1.0)
combined_model2.compile(optimizer=optimiser2, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
pca_layers = [layer.name for layer in pca_model.layers]
ts_layers = [layer.name for layer in ts_model.layers]
combined_layers = [layer.name for layer in combined_model2.layers]

# The layers which are shared between both components of the model.
shared_layers = list(set(combined_layers) - set(pca_layers) - set(ts_layers))

pca_component_layers = pca_layers + shared_layers
ts_component_layers = ts_layers + shared_layers

# %%
# Custom training loop
epochs = 25

# Keras optimisers are tied to the weights they are created with
comb_optimiser = Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999, epsilon=1e-08)
ts_optimiser = Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999, epsilon=1e-08)
pca_optimiser = Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999, epsilon=1e-08)

for epoch in range(epochs):
    print(f'Epoch {epoch+1}/{epochs}')

    # Freeze the PCA component and CNN-ResBiGRU component and train the combination component
    for layer in combined_model2.layers:  # Adjust indices based on your model's architecture
        if layer.name in shared_layers:
            layer.trainable = True
        else:
            layer.trainable = False
    # Keras optimisers are tied to the weights they are created with
    combined_model2.compile(optimizer= comb_optimiser, loss='categorical_crossentropy', metrics=['accuracy'])
    combined_model2.fit(train_rr_ds, validation_data = val_rr_ds, epochs=5, verbose=1, callbacks = [reduce_lr])

    # Freeze the PCA component and combination component and train the CNN-ResBiGRU component
    for layer in combined_model2.layers:  # Adjust indices based on your model's architecture
        if layer.name in ts_layers:
            layer.trainable = True
        else:
            layer.trainable = False

    combined_model2.compile(optimizer= ts_optimiser, loss='categorical_crossentropy', metrics=['accuracy'])
    combined_model2.fit(train_rr_ds, validation_data = val_rr_ds, epochs=3, verbose=1, callbacks = [reduce_lr])

    # Freeze the CNN-ResBiGRU component and combination component and train the PCA component
    for layer in combined_model2.layers:  # Adjust indices based on your model's architecture
        if layer.name in pca_layers:
            layer.trainable = True
        else:
            layer.trainable = False

    combined_model2.compile(optimizer= pca_optimiser, loss='categorical_crossentropy', metrics=['accuracy'])
    combined_model2.fit(train_rr_ds, validation_data = val_rr_ds, epochs=2, verbose=1, callbacks = [reduce_lr])
# Out:
# Epoch 1/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.6878 - loss: 1.0188 - val_accuracy: 0.5948 - val_loss: 1.7074 - learning_rate: 0.0010
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7963 - loss: 0.6542 - val_accuracy: 0.6078 - val_loss: 1.5460 - learning_rate: 0.0010
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8200 - loss: 0.5092 - val_accuracy: 0.6286 - val_loss: 1.3567 - learning_rate: 0.0010
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8592 - loss: 0.4023 - val_accuracy: 0.6458 - val_loss: 1.3126 - learning_rate: 0.0010
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8840 - loss: 0.3533 - val_accuracy: 0.6552 - val_loss: 1.3140 - learning_rate: 0.0010
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 30s 237ms/step - accuracy: 0.8210 - loss: 0.5572 - val_accuracy: 0.6286 - val_loss: 1.5856 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.8845 - loss: 0.3304 - val_accuracy: 0.6932 - val_loss: 1.2892 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9053 - loss: 0.2589 - val_accuracy: 0.6717 - val_loss: 1.2600 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - accuracy: 0.9373 - loss: 0.1961 - val_accuracy: 0.6861 - val_loss: 1.2051 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9676 - loss: 0.1181 - val_accuracy: 0.6925 - val_loss: 1.1669 - learning_rate: 0.0010
# Epoch 2/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.9761 - loss: 0.0976 - val_accuracy: 0.6997 - val_loss: 1.1418 - learning_rate: 0.0010
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9767 - loss: 0.0841 - val_accuracy: 0.7062 - val_loss: 1.1089 - learning_rate: 0.0010
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9814 - loss: 0.0799 - val_accuracy: 0.7134 - val_loss: 1.0980 - learning_rate: 0.0010
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9856 - loss: 0.0721 - val_accuracy: 0.7184 - val_loss: 1.0932 - learning_rate: 0.0010
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9795 - loss: 0.0704 - val_accuracy: 0.7198 - val_loss: 1.1041 - learning_rate: 0.0010
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.9645 - loss: 0.1032 - val_accuracy: 0.7177 - val_loss: 0.9815 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9741 - loss: 0.0826 - val_accuracy: 0.7155 - val_loss: 1.0764 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9828 - loss: 0.0643 - val_accuracy: 0.7299 - val_loss: 1.0124 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - accuracy: 0.9940 - loss: 0.0356 - val_accuracy: 0.7313 - val_loss: 1.0009 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9925 - loss: 0.0339 - val_accuracy: 0.7335 - val_loss: 0.9937 - learning_rate: 0.0010
# Epoch 3/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.9974 - loss: 0.0259 - val_accuracy: 0.7313 - val_loss: 1.0072 - learning_rate: 0.0010
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9974 - loss: 0.0262 - val_accuracy: 0.7306 - val_loss: 1.0059 - learning_rate: 0.0010
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9955 - loss: 0.0250 - val_accuracy: 0.7335 - val_loss: 0.9999 - learning_rate: 0.0010
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9959 - loss: 0.0271 - val_accuracy: 0.7349 - val_loss: 0.9962 - learning_rate: 0.0010
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9978 - loss: 0.0235 - val_accuracy: 0.7356 - val_loss: 0.9999 - learning_rate: 0.0010
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 237ms/step - accuracy: 0.9922 - loss: 0.0378 - val_accuracy: 0.7471 - val_loss: 0.9512 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9904 - loss: 0.0413 - val_accuracy: 0.7500 - val_loss: 0.9919 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9902 - loss: 0.0366 - val_accuracy: 0.7421 - val_loss: 0.9327 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - accuracy: 0.9954 - loss: 0.0226 - val_accuracy: 0.7428 - val_loss: 0.9267 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9965 - loss: 0.0208 - val_accuracy: 0.7443 - val_loss: 0.9232 - learning_rate: 0.0010
# Epoch 4/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.9982 - loss: 0.0164 - val_accuracy: 0.7457 - val_loss: 0.9192 - learning_rate: 0.0010
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9996 - loss: 0.0142 - val_accuracy: 0.7486 - val_loss: 0.9220 - learning_rate: 0.0010
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9979 - loss: 0.0156 - val_accuracy: 0.7478 - val_loss: 0.9289 - learning_rate: 0.0010
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9999 - loss: 0.0130 - val_accuracy: 0.7478 - val_loss: 0.9370 - learning_rate: 0.0010
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9981 - loss: 0.0137 - val_accuracy: 0.7471 - val_loss: 0.9364 - learning_rate: 5.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 238ms/step - accuracy: 0.9949 - loss: 0.0251 - val_accuracy: 0.7486 - val_loss: 0.9291 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9935 - loss: 0.0272 - val_accuracy: 0.7392 - val_loss: 0.9902 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9939 - loss: 0.0257 - val_accuracy: 0.7364 - val_loss: 0.9593 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 98ms/step - accuracy: 0.9986 - loss: 0.0127 - val_accuracy: 0.7385 - val_loss: 0.9583 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9989 - loss: 0.0132 - val_accuracy: 0.7378 - val_loss: 0.9566 - learning_rate: 0.0010
# Epoch 5/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.9996 - loss: 0.0111 - val_accuracy: 0.7392 - val_loss: 0.9537 - learning_rate: 5.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9993 - loss: 0.0098 - val_accuracy: 0.7399 - val_loss: 0.9480 - learning_rate: 5.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9999 - loss: 0.0086 - val_accuracy: 0.7378 - val_loss: 0.9405 - learning_rate: 5.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.7407 - val_loss: 0.9310 - learning_rate: 5.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9999 - loss: 0.0089 - val_accuracy: 0.7414 - val_loss: 0.9256 - learning_rate: 5.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 237ms/step - accuracy: 0.9974 - loss: 0.0187 - val_accuracy: 0.7399 - val_loss: 0.9045 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9962 - loss: 0.0195 - val_accuracy: 0.7421 - val_loss: 0.9409 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9978 - loss: 0.0156 - val_accuracy: 0.7478 - val_loss: 0.9032 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.9995 - loss: 0.0096 - val_accuracy: 0.7493 - val_loss: 0.9035 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9998 - loss: 0.0087 - val_accuracy: 0.7493 - val_loss: 0.9013 - learning_rate: 0.0010
# Epoch 6/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.9998 - loss: 0.0074 - val_accuracy: 0.7464 - val_loss: 0.8971 - learning_rate: 5.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9985 - loss: 0.0078 - val_accuracy: 0.7486 - val_loss: 0.8932 - learning_rate: 5.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.7478 - val_loss: 0.8899 - learning_rate: 5.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.7478 - val_loss: 0.8918 - learning_rate: 5.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9994 - loss: 0.0069 - val_accuracy: 0.7450 - val_loss: 0.8935 - learning_rate: 5.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 235ms/step - accuracy: 0.9978 - loss: 0.0131 - val_accuracy: 0.7493 - val_loss: 0.9057 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.9984 - loss: 0.0154 - val_accuracy: 0.7536 - val_loss: 0.9429 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9981 - loss: 0.0129 - val_accuracy: 0.7435 - val_loss: 0.9513 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.9996 - loss: 0.0080 - val_accuracy: 0.7428 - val_loss: 0.9505 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9988 - loss: 0.0077 - val_accuracy: 0.7407 - val_loss: 0.9488 - learning_rate: 0.0010
# Epoch 7/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.9986 - loss: 0.0080 - val_accuracy: 0.7414 - val_loss: 0.9476 - learning_rate: 5.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.7421 - val_loss: 0.9456 - learning_rate: 5.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.7450 - val_loss: 0.9440 - learning_rate: 5.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9999 - loss: 0.0056 - val_accuracy: 0.7464 - val_loss: 0.9404 - learning_rate: 5.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.7457 - val_loss: 0.9370 - learning_rate: 5.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 239ms/step - accuracy: 0.9973 - loss: 0.0125 - val_accuracy: 0.7378 - val_loss: 0.9567 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9986 - loss: 0.0149 - val_accuracy: 0.7529 - val_loss: 0.9366 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9972 - loss: 0.0158 - val_accuracy: 0.7407 - val_loss: 1.0218 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.9999 - loss: 0.0076 - val_accuracy: 0.7421 - val_loss: 1.0188 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.7435 - val_loss: 1.0139 - learning_rate: 0.0010
# Epoch 8/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.9994 - loss: 0.0065 - val_accuracy: 0.7443 - val_loss: 1.0117 - learning_rate: 5.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.7443 - val_loss: 1.0085 - learning_rate: 5.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9997 - loss: 0.0065 - val_accuracy: 0.7443 - val_loss: 1.0053 - learning_rate: 5.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9994 - loss: 0.0056 - val_accuracy: 0.7464 - val_loss: 1.0020 - learning_rate: 5.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.7471 - val_loss: 0.9934 - learning_rate: 5.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.9984 - loss: 0.0118 - val_accuracy: 0.7443 - val_loss: 0.9557 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9987 - loss: 0.0110 - val_accuracy: 0.7378 - val_loss: 1.0708 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9993 - loss: 0.0089 - val_accuracy: 0.7565 - val_loss: 0.8900 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 96ms/step - accuracy: 0.9992 - loss: 0.0070 - val_accuracy: 0.7586 - val_loss: 0.8908 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9998 - loss: 0.0057 - val_accuracy: 0.7622 - val_loss: 0.8954 - learning_rate: 0.0010
# Epoch 9/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.9998 - loss: 0.0048 - val_accuracy: 0.7629 - val_loss: 0.8960 - learning_rate: 5.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.7644 - val_loss: 0.9035 - learning_rate: 5.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.7622 - val_loss: 0.9083 - learning_rate: 5.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.7601 - val_loss: 0.9089 - learning_rate: 5.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.7608 - val_loss: 0.9102 - learning_rate: 2.5000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.9992 - loss: 0.0100 - val_accuracy: 0.7716 - val_loss: 0.8505 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.9963 - loss: 0.0116 - val_accuracy: 0.7536 - val_loss: 0.9290 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.9985 - loss: 0.0089 - val_accuracy: 0.7421 - val_loss: 0.9737 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.7421 - val_loss: 0.9785 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.7428 - val_loss: 0.9778 - learning_rate: 0.0010
# Epoch 10/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.7443 - val_loss: 0.9772 - learning_rate: 2.5000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.7443 - val_loss: 0.9713 - learning_rate: 2.5000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.7421 - val_loss: 0.9660 - learning_rate: 2.5000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.7435 - val_loss: 0.9611 - learning_rate: 2.5000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.7450 - val_loss: 0.9551 - learning_rate: 2.5000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 237ms/step - accuracy: 0.9997 - loss: 0.0074 - val_accuracy: 0.7493 - val_loss: 0.9595 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9973 - loss: 0.0113 - val_accuracy: 0.7493 - val_loss: 0.9409 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9937 - loss: 0.0231 - val_accuracy: 0.7744 - val_loss: 0.8947 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.9937 - loss: 0.0203 - val_accuracy: 0.7744 - val_loss: 0.8941 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9982 - loss: 0.0123 - val_accuracy: 0.7730 - val_loss: 0.9003 - learning_rate: 0.0010
# Epoch 11/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.9998 - loss: 0.0055 - val_accuracy: 0.7723 - val_loss: 0.9007 - learning_rate: 2.5000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9999 - loss: 0.0050 - val_accuracy: 0.7716 - val_loss: 0.9057 - learning_rate: 2.5000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.7694 - val_loss: 0.9117 - learning_rate: 2.5000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9999 - loss: 0.0040 - val_accuracy: 0.7680 - val_loss: 0.9152 - learning_rate: 2.5000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.7680 - val_loss: 0.9140 - learning_rate: 1.2500e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 238ms/step - accuracy: 0.9982 - loss: 0.0118 - val_accuracy: 0.7536 - val_loss: 0.9982 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9981 - loss: 0.0115 - val_accuracy: 0.7493 - val_loss: 0.8986 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9983 - loss: 0.0104 - val_accuracy: 0.7759 - val_loss: 0.8765 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - accuracy: 0.9998 - loss: 0.0052 - val_accuracy: 0.7766 - val_loss: 0.8973 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9998 - loss: 0.0069 - val_accuracy: 0.7759 - val_loss: 0.8926 - learning_rate: 0.0010
# Epoch 12/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.9999 - loss: 0.0043 - val_accuracy: 0.7751 - val_loss: 0.8882 - learning_rate: 1.2500e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.7744 - val_loss: 0.8797 - learning_rate: 1.2500e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.7751 - val_loss: 0.8723 - learning_rate: 1.2500e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.7723 - val_loss: 0.8679 - learning_rate: 1.2500e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.7737 - val_loss: 0.8647 - learning_rate: 1.2500e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 237ms/step - accuracy: 0.9978 - loss: 0.0100 - val_accuracy: 0.7529 - val_loss: 0.9613 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9986 - loss: 0.0104 - val_accuracy: 0.7392 - val_loss: 1.0094 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9977 - loss: 0.0093 - val_accuracy: 0.7421 - val_loss: 1.0618 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - accuracy: 0.9993 - loss: 0.0057 - val_accuracy: 0.7435 - val_loss: 1.0583 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9996 - loss: 0.0048 - val_accuracy: 0.7428 - val_loss: 1.0542 - learning_rate: 0.0010
# Epoch 13/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.7435 - val_loss: 1.0534 - learning_rate: 1.2500e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.7435 - val_loss: 1.0500 - learning_rate: 1.2500e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.7435 - val_loss: 1.0465 - learning_rate: 1.2500e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9998 - loss: 0.0037 - val_accuracy: 0.7443 - val_loss: 1.0432 - learning_rate: 1.2500e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9996 - loss: 0.0036 - val_accuracy: 0.7435 - val_loss: 1.0409 - learning_rate: 1.2500e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.9976 - loss: 0.0095 - val_accuracy: 0.7651 - val_loss: 0.9677 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9996 - loss: 0.0080 - val_accuracy: 0.7565 - val_loss: 0.8837 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9999 - loss: 0.0073 - val_accuracy: 0.7486 - val_loss: 0.9420 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 97ms/step - accuracy: 0.9998 - loss: 0.0044 - val_accuracy: 0.7507 - val_loss: 0.9365 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9998 - loss: 0.0040 - val_accuracy: 0.7507 - val_loss: 0.9318 - learning_rate: 0.0010
# Epoch 14/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.9991 - loss: 0.0038 - val_accuracy: 0.7507 - val_loss: 0.9322 - learning_rate: 1.2500e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.7514 - val_loss: 0.9328 - learning_rate: 1.2500e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.7543 - val_loss: 0.9338 - learning_rate: 1.2500e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.7550 - val_loss: 0.9344 - learning_rate: 1.2500e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.7565 - val_loss: 0.9342 - learning_rate: 1.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 235ms/step - accuracy: 0.9999 - loss: 0.0059 - val_accuracy: 0.7565 - val_loss: 0.9365 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9990 - loss: 0.0081 - val_accuracy: 0.7751 - val_loss: 0.8979 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9971 - loss: 0.0108 - val_accuracy: 0.7708 - val_loss: 0.8849 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.9998 - loss: 0.0036 - val_accuracy: 0.7708 - val_loss: 0.8850 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9998 - loss: 0.0032 - val_accuracy: 0.7694 - val_loss: 0.8869 - learning_rate: 0.0010
# Epoch 15/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.9998 - loss: 0.0030 - val_accuracy: 0.7694 - val_loss: 0.8872 - learning_rate: 1.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7672 - val_loss: 0.8882 - learning_rate: 1.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.7672 - val_loss: 0.8888 - learning_rate: 1.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.7665 - val_loss: 0.8891 - learning_rate: 1.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9989 - loss: 0.0039 - val_accuracy: 0.7672 - val_loss: 0.8898 - learning_rate: 1.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 234ms/step - accuracy: 0.9990 - loss: 0.0080 - val_accuracy: 0.7629 - val_loss: 0.9179 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9992 - loss: 0.0084 - val_accuracy: 0.7730 - val_loss: 0.8975 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9993 - loss: 0.0073 - val_accuracy: 0.7557 - val_loss: 1.0019 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - accuracy: 0.9997 - loss: 0.0033 - val_accuracy: 0.7550 - val_loss: 1.0030 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.7593 - val_loss: 0.9950 - learning_rate: 0.0010
# Epoch 16/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.7601 - val_loss: 0.9960 - learning_rate: 1.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.7593 - val_loss: 0.9940 - learning_rate: 1.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9998 - loss: 0.0023 - val_accuracy: 0.7593 - val_loss: 0.9898 - learning_rate: 1.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.7579 - val_loss: 0.9822 - learning_rate: 1.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.7572 - val_loss: 0.9755 - learning_rate: 1.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 238ms/step - accuracy: 0.9986 - loss: 0.0075 - val_accuracy: 0.7550 - val_loss: 1.0050 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9994 - loss: 0.0047 - val_accuracy: 0.7651 - val_loss: 0.9500 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9988 - loss: 0.0070 - val_accuracy: 0.7680 - val_loss: 0.9496 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.7680 - val_loss: 0.9442 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7687 - val_loss: 0.9394 - learning_rate: 0.0010
# Epoch 17/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.7672 - val_loss: 0.9360 - learning_rate: 1.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9997 - loss: 0.0028 - val_accuracy: 0.7672 - val_loss: 0.9340 - learning_rate: 1.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.7680 - val_loss: 0.9336 - learning_rate: 1.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.7687 - val_loss: 0.9339 - learning_rate: 1.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.7687 - val_loss: 0.9345 - learning_rate: 1.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 28s 238ms/step - accuracy: 0.9996 - loss: 0.0051 - val_accuracy: 0.7830 - val_loss: 0.8985 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9977 - loss: 0.0082 - val_accuracy: 0.7716 - val_loss: 0.9102 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9990 - loss: 0.0059 - val_accuracy: 0.7550 - val_loss: 0.9890 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.7536 - val_loss: 0.9857 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.7536 - val_loss: 0.9847 - learning_rate: 0.0010
# Epoch 18/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7536 - val_loss: 0.9854 - learning_rate: 1.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.7557 - val_loss: 0.9832 - learning_rate: 1.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.7572 - val_loss: 0.9803 - learning_rate: 1.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7579 - val_loss: 0.9759 - learning_rate: 1.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.7565 - val_loss: 0.9730 - learning_rate: 1.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 238ms/step - accuracy: 0.9984 - loss: 0.0051 - val_accuracy: 0.7414 - val_loss: 1.0057 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9994 - loss: 0.0053 - val_accuracy: 0.7565 - val_loss: 0.9915 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.9999 - loss: 0.0041 - val_accuracy: 0.7529 - val_loss: 0.9563 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.9998 - loss: 0.0027 - val_accuracy: 0.7514 - val_loss: 0.9590 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.7507 - val_loss: 0.9606 - learning_rate: 0.0010
# Epoch 19/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.7500 - val_loss: 0.9619 - learning_rate: 1.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.7507 - val_loss: 0.9636 - learning_rate: 1.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.7522 - val_loss: 0.9647 - learning_rate: 1.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7529 - val_loss: 0.9661 - learning_rate: 1.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.7514 - val_loss: 0.9676 - learning_rate: 1.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 238ms/step - accuracy: 0.9998 - loss: 0.0046 - val_accuracy: 0.7529 - val_loss: 0.9800 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9993 - loss: 0.0054 - val_accuracy: 0.7507 - val_loss: 0.9551 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9981 - loss: 0.0074 - val_accuracy: 0.7522 - val_loss: 0.9501 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 96ms/step - accuracy: 0.9966 - loss: 0.0089 - val_accuracy: 0.7514 - val_loss: 0.9496 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9981 - loss: 0.0068 - val_accuracy: 0.7529 - val_loss: 0.9484 - learning_rate: 0.0010
# Epoch 20/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.9998 - loss: 0.0032 - val_accuracy: 0.7522 - val_loss: 0.9516 - learning_rate: 1.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9987 - loss: 0.0050 - val_accuracy: 0.7529 - val_loss: 0.9546 - learning_rate: 1.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7536 - val_loss: 0.9558 - learning_rate: 1.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.7536 - val_loss: 0.9564 - learning_rate: 1.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.7522 - val_loss: 0.9580 - learning_rate: 1.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 237ms/step - accuracy: 0.9987 - loss: 0.0077 - val_accuracy: 0.7443 - val_loss: 1.0222 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9973 - loss: 0.0100 - val_accuracy: 0.7615 - val_loss: 1.0907 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9992 - loss: 0.0053 - val_accuracy: 0.7644 - val_loss: 0.8573 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.9989 - loss: 0.0058 - val_accuracy: 0.7658 - val_loss: 0.8567 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.7658 - val_loss: 0.8571 - learning_rate: 0.0010
# Epoch 21/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.7644 - val_loss: 0.8595 - learning_rate: 1.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.7644 - val_loss: 0.8605 - learning_rate: 1.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7651 - val_loss: 0.8627 - learning_rate: 1.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7658 - val_loss: 0.8622 - learning_rate: 1.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.7651 - val_loss: 0.8600 - learning_rate: 1.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 237ms/step - accuracy: 0.9988 - loss: 0.0071 - val_accuracy: 0.7557 - val_loss: 0.9346 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9990 - loss: 0.0063 - val_accuracy: 0.7550 - val_loss: 0.9514 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9994 - loss: 0.0059 - val_accuracy: 0.7802 - val_loss: 0.8870 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.7787 - val_loss: 0.8929 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7780 - val_loss: 0.8980 - learning_rate: 0.0010
# Epoch 22/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.7773 - val_loss: 0.8976 - learning_rate: 1.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.7773 - val_loss: 0.8986 - learning_rate: 1.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.7795 - val_loss: 0.9014 - learning_rate: 1.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.7773 - val_loss: 0.9043 - learning_rate: 1.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.7730 - val_loss: 0.9074 - learning_rate: 1.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.9999 - loss: 0.0037 - val_accuracy: 0.7586 - val_loss: 1.0105 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9994 - loss: 0.0035 - val_accuracy: 0.7536 - val_loss: 0.9308 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9998 - loss: 0.0033 - val_accuracy: 0.7529 - val_loss: 1.0124 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7514 - val_loss: 1.0203 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.7514 - val_loss: 1.0241 - learning_rate: 0.0010
# Epoch 23/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.7507 - val_loss: 1.0279 - learning_rate: 1.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.7529 - val_loss: 1.0293 - learning_rate: 1.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.7529 - val_loss: 1.0288 - learning_rate: 1.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.7529 - val_loss: 1.0269 - learning_rate: 1.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.7550 - val_loss: 1.0249 - learning_rate: 1.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.9996 - loss: 0.0032 - val_accuracy: 0.7522 - val_loss: 1.0308 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9993 - loss: 0.0038 - val_accuracy: 0.7608 - val_loss: 1.0452 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.7680 - val_loss: 0.9195 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7701 - val_loss: 0.9225 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.7694 - val_loss: 0.9231 - learning_rate: 0.0010
# Epoch 24/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.7694 - val_loss: 0.9219 - learning_rate: 1.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.7665 - val_loss: 0.9206 - learning_rate: 1.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.7651 - val_loss: 0.9191 - learning_rate: 1.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.7658 - val_loss: 0.9185 - learning_rate: 1.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.7658 - val_loss: 0.9186 - learning_rate: 1.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 237ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.7708 - val_loss: 0.9687 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9998 - loss: 0.0032 - val_accuracy: 0.7557 - val_loss: 0.9812 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.9995 - loss: 0.0040 - val_accuracy: 0.7593 - val_loss: 0.8758 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.9997 - loss: 0.0027 - val_accuracy: 0.7608 - val_loss: 0.8756 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7665 - val_loss: 0.8769 - learning_rate: 0.0010
# Epoch 25/25
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.7680 - val_loss: 0.8778 - learning_rate: 1.0000e-04
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.7651 - val_loss: 0.8797 - learning_rate: 1.0000e-04
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.7658 - val_loss: 0.8809 - learning_rate: 1.0000e-04
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9998 - loss: 0.0015 - val_accuracy: 0.7629 - val_loss: 0.8822 - learning_rate: 1.0000e-04
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.7622 - val_loss: 0.8831 - learning_rate: 1.0000e-04
# Epoch 1/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 27s 236ms/step - accuracy: 0.9993 - loss: 0.0041 - val_accuracy: 0.7629 - val_loss: 0.9740 - learning_rate: 0.0010
# Epoch 2/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9995 - loss: 0.0035 - val_accuracy: 0.7593 - val_loss: 0.8914 - learning_rate: 0.0010
# Epoch 3/3
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9994 - loss: 0.0044 - val_accuracy: 0.7629 - val_loss: 1.0110 - learning_rate: 0.0010
# Epoch 1/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.9999 - loss: 0.0031 - val_accuracy: 0.7593 - val_loss: 1.0060 - learning_rate: 0.0010
# Epoch 2/2
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9994 - loss: 0.0025 - val_accuracy: 0.7586 - val_loss: 0.9907 - learning_rate: 0.0010

# %%
combined_model2.save('../models/BlockRocketExperiments/combined_model2.keras')

# %%
# Load the model
custom_objects = {'ConvBlock': ConvBlock, 'ResBiGRU': ResBiGRU}
combined_model2 = load_model('../models/BlockRocketExperiments/combined_model2.keras', custom_objects=custom_objects)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'adam', because it has 54 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
combined2_results_val = combined_model2.evaluate(val_rr_ds, batch_size=128)
combined2_results_test = combined_model2.evaluate(test_rr_ds, batch_size=128)
print("Validation Loss: {}\nValidation Accuracy: {}".format(*combined2_results_val))
print("Test Loss: {}\nTest Accuracy: {}".format(*combined2_results_test))
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.7353 - loss: 1.0765
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.6769 - loss: 1.6901
# Validation Loss: 0.9906644225120544
# Validation Accuracy: 0.7586206793785095
# Test Loss: 1.6279574632644653
# Test Accuracy: 0.6860133409500122

# %%
predictions_combined2_val = combined_model2.predict((val_pca_tf, val_raw_tf), batch_size=128)
predictions_combined2_test = combined_model2.predict((test_pca_tf, test_raw_tf), batch_size=128)

predictions_combined2_val =tf.argmax(predictions_combined2_val, axis = 1)
predictions_combined2_test = tf.argmax(predictions_combined2_test, axis = 1)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step

# %%
# Compare predictions against the targets
print("Validation Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions_combined2_val), sum(np.equal(predictions_combined2_val, y_val))))
print("Test Data - Total predictions made: %s. Number of correct predictions: %s" % (len(predictions_combined2_test), sum(np.equal(predictions_combined2_test, y_test))))
# Out:
# Validation Data - Total predictions made: 1392. Number of correct predictions: 1056
# Test Data - Total predictions made: 1051. Number of correct predictions: 721

# %% [markdown]
# #### **3.2.3: Using Keras (Simultaneous Training)**

# %%
combined_model3 = Model(inputs= {"raw": ts_model.input, "pca": pca_model.input}, outputs = final_output)
combined_model3.summary()
# Out:
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ raw (InputLayer)          │ (None, 149, 6)         │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_ConvBlock1 (ConvBlock) │ (None, 149, 32)        │          2,080 │ raw[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_ConvBlock2 (ConvBlock) │ (None, 149, 32)        │         10,400 │ ts_ConvBlock1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_ResBiGRU1 (ResBiGRU)   │ (None, 149, 64)        │         25,408 │ ts_ConvBlock2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pca (InputLayer)          │ (None, 128)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_GlobalMaxPooling       │ (None, 64)             │              0 │ ts_ResBiGRU1[0][0]     │
# │ (GlobalMaxPooling1D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pca_BatchNorm             │ (None, 128)            │            512 │ pca[0][0]              │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_BatchNorm              │ (None, 64)             │            256 │ ts_GlobalMaxPooling[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pca_Dense (Dense)         │ (None, 64)             │          8,256 │ pca_BatchNorm[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 128)            │              0 │ ts_BatchNorm[0][0],    │
# │                           │                        │                │ pca_Dense[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ comb_Dense2 (Dense)       │ (None, 31)             │          3,999 │ concatenate[0][0]      │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 50,911 (198.87 KB)
#  Trainable params: 8,512 (33.25 KB)
#  Non-trainable params: 42,399 (165.62 KB)

# %%
combined_model3 = copy_model_weights(source = pretrained_rocket_model, target = combined_model3, mapping = rocket_layer_mapping)
combined_model3 = copy_model_weights(source = pretrained_cnnresbigru_model, target = combined_model3, mapping = ts_layer_mapping)
# Out:
# Copied weights from pca_Dense to pca_Dense
# Copied weights from pca_BatchNorm to pca_BatchNorm
# Could not copy weights from ts_ConvBlock1 to ts_ConvBlock1: No such layer: ts_ConvBlock1. Existing layers are: ['raw', 'ts_ConvBlock', 'ts_ConvBlock2', 'ts_ResBiGRU1', 'ts_GlobalMaxPooling', 'ts_BatchNorm', 'dense_22'].
# Copied weights from ts_ConvBlock2 to ts_ConvBlock2
# Copied weights from ts_ResBiGRU1 to ts_ResBiGRU1
# Copied weights from ts_GlobalMaxPooling to ts_GlobalMaxPooling
# Copied weights from ts_BatchNorm to ts_BatchNorm

# %%
optimiser3 = Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999, epsilon=1e-08, clipnorm=1.0)
combined_model3.compile(optimizer=optimiser3, loss='categorical_crossentropy', metrics=['accuracy'])
history_2 = combined_model3.fit(train_rr_ds, validation_data=val_rr_ds, epochs=50, verbose = 1, callbacks = [reduce_lr])
# Out:
# Epoch 1/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - accuracy: 0.9678 - loss: 0.1024 - val_accuracy: 0.7299 - val_loss: 1.1635 - learning_rate: 0.0010
# Epoch 2/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9816 - loss: 0.0633 - val_accuracy: 0.7306 - val_loss: 1.1492 - learning_rate: 0.0010
# Epoch 3/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9892 - loss: 0.0481 - val_accuracy: 0.7270 - val_loss: 1.1500 - learning_rate: 0.0010
# Epoch 4/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9872 - loss: 0.0470 - val_accuracy: 0.7284 - val_loss: 1.1571 - learning_rate: 0.0010
# Epoch 5/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9909 - loss: 0.0410 - val_accuracy: 0.7299 - val_loss: 1.1628 - learning_rate: 0.0010
# Epoch 6/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9925 - loss: 0.0367 - val_accuracy: 0.7313 - val_loss: 1.1665 - learning_rate: 5.0000e-04
# Epoch 7/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9934 - loss: 0.0316 - val_accuracy: 0.7313 - val_loss: 1.1694 - learning_rate: 5.0000e-04
# Epoch 8/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9900 - loss: 0.0348 - val_accuracy: 0.7292 - val_loss: 1.1702 - learning_rate: 5.0000e-04
# Epoch 9/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9943 - loss: 0.0331 - val_accuracy: 0.7284 - val_loss: 1.1705 - learning_rate: 2.5000e-04
# Epoch 10/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9935 - loss: 0.0334 - val_accuracy: 0.7277 - val_loss: 1.1706 - learning_rate: 2.5000e-04
# Epoch 11/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9948 - loss: 0.0291 - val_accuracy: 0.7277 - val_loss: 1.1695 - learning_rate: 2.5000e-04
# Epoch 12/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9941 - loss: 0.0319 - val_accuracy: 0.7277 - val_loss: 1.1691 - learning_rate: 1.2500e-04
# Epoch 13/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9964 - loss: 0.0281 - val_accuracy: 0.7277 - val_loss: 1.1696 - learning_rate: 1.2500e-04
# Epoch 14/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9947 - loss: 0.0276 - val_accuracy: 0.7270 - val_loss: 1.1694 - learning_rate: 1.2500e-04
# Epoch 15/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9939 - loss: 0.0299 - val_accuracy: 0.7277 - val_loss: 1.1689 - learning_rate: 1.0000e-04
# Epoch 16/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9933 - loss: 0.0306 - val_accuracy: 0.7284 - val_loss: 1.1688 - learning_rate: 1.0000e-04
# Epoch 17/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9956 - loss: 0.0270 - val_accuracy: 0.7292 - val_loss: 1.1683 - learning_rate: 1.0000e-04
# Epoch 18/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9941 - loss: 0.0299 - val_accuracy: 0.7292 - val_loss: 1.1678 - learning_rate: 1.0000e-04
# Epoch 19/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9939 - loss: 0.0298 - val_accuracy: 0.7292 - val_loss: 1.1674 - learning_rate: 1.0000e-04
# Epoch 20/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9973 - loss: 0.0265 - val_accuracy: 0.7292 - val_loss: 1.1666 - learning_rate: 1.0000e-04
# Epoch 21/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9946 - loss: 0.0263 - val_accuracy: 0.7292 - val_loss: 1.1668 - learning_rate: 1.0000e-04
# Epoch 22/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9954 - loss: 0.0278 - val_accuracy: 0.7306 - val_loss: 1.1671 - learning_rate: 1.0000e-04
# Epoch 23/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9957 - loss: 0.0291 - val_accuracy: 0.7299 - val_loss: 1.1674 - learning_rate: 1.0000e-04
# Epoch 24/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9937 - loss: 0.0288 - val_accuracy: 0.7299 - val_loss: 1.1677 - learning_rate: 1.0000e-04
# Epoch 25/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9971 - loss: 0.0248 - val_accuracy: 0.7299 - val_loss: 1.1678 - learning_rate: 1.0000e-04
# Epoch 26/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9969 - loss: 0.0263 - val_accuracy: 0.7299 - val_loss: 1.1685 - learning_rate: 1.0000e-04
# Epoch 27/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9940 - loss: 0.0279 - val_accuracy: 0.7306 - val_loss: 1.1692 - learning_rate: 1.0000e-04
# Epoch 28/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9969 - loss: 0.0261 - val_accuracy: 0.7306 - val_loss: 1.1698 - learning_rate: 1.0000e-04
# Epoch 29/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9943 - loss: 0.0275 - val_accuracy: 0.7306 - val_loss: 1.1702 - learning_rate: 1.0000e-04
# Epoch 30/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9967 - loss: 0.0263 - val_accuracy: 0.7306 - val_loss: 1.1706 - learning_rate: 1.0000e-04
# Epoch 31/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9956 - loss: 0.0279 - val_accuracy: 0.7306 - val_loss: 1.1707 - learning_rate: 1.0000e-04
# Epoch 32/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9956 - loss: 0.0245 - val_accuracy: 0.7299 - val_loss: 1.1712 - learning_rate: 1.0000e-04
# Epoch 33/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9957 - loss: 0.0239 - val_accuracy: 0.7299 - val_loss: 1.1714 - learning_rate: 1.0000e-04
# Epoch 34/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9964 - loss: 0.0244 - val_accuracy: 0.7299 - val_loss: 1.1718 - learning_rate: 1.0000e-04
# Epoch 35/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9966 - loss: 0.0241 - val_accuracy: 0.7299 - val_loss: 1.1713 - learning_rate: 1.0000e-04
# Epoch 36/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9975 - loss: 0.0218 - val_accuracy: 0.7299 - val_loss: 1.1709 - learning_rate: 1.0000e-04
# Epoch 37/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9968 - loss: 0.0225 - val_accuracy: 0.7299 - val_loss: 1.1714 - learning_rate: 1.0000e-04
# Epoch 38/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9982 - loss: 0.0258 - val_accuracy: 0.7299 - val_loss: 1.1706 - learning_rate: 1.0000e-04
# Epoch 39/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9949 - loss: 0.0258 - val_accuracy: 0.7299 - val_loss: 1.1709 - learning_rate: 1.0000e-04
# Epoch 40/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9964 - loss: 0.0230 - val_accuracy: 0.7299 - val_loss: 1.1709 - learning_rate: 1.0000e-04
# Epoch 41/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9959 - loss: 0.0243 - val_accuracy: 0.7292 - val_loss: 1.1707 - learning_rate: 1.0000e-04
# Epoch 42/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9964 - loss: 0.0250 - val_accuracy: 0.7299 - val_loss: 1.1702 - learning_rate: 1.0000e-04
# Epoch 43/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9938 - loss: 0.0290 - val_accuracy: 0.7299 - val_loss: 1.1697 - learning_rate: 1.0000e-04
# Epoch 44/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9955 - loss: 0.0249 - val_accuracy: 0.7292 - val_loss: 1.1696 - learning_rate: 1.0000e-04
# Epoch 45/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9964 - loss: 0.0226 - val_accuracy: 0.7284 - val_loss: 1.1701 - learning_rate: 1.0000e-04
# Epoch 46/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9973 - loss: 0.0201 - val_accuracy: 0.7284 - val_loss: 1.1709 - learning_rate: 1.0000e-04
# Epoch 47/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9984 - loss: 0.0222 - val_accuracy: 0.7284 - val_loss: 1.1713 - learning_rate: 1.0000e-04
# Epoch 48/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9974 - loss: 0.0222 - val_accuracy: 0.7270 - val_loss: 1.1716 - learning_rate: 1.0000e-04
# Epoch 49/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9974 - loss: 0.0211 - val_accuracy: 0.7277 - val_loss: 1.1723 - learning_rate: 1.0000e-04
# Epoch 50/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9982 - loss: 0.0219 - val_accuracy: 0.7284 - val_loss: 1.1727 - learning_rate: 1.0000e-04

# %% [markdown]
# #### **3.2.4: Using Keras (Simultaneous Training) with no pre-training**

# %%
combined_model5 = Model(inputs= {"raw": ts_model.input, "pca": pca_model.input}, outputs = final_output)
combined_model5.summary()
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ raw (InputLayer)          │ (None, 149, 6)         │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_ConvBlock1 (ConvBlock) │ (None, 149, 32)        │          2,080 │ raw[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_ConvBlock2 (ConvBlock) │ (None, 149, 32)        │         10,400 │ ts_ConvBlock1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_ResBiGRU1 (ResBiGRU)   │ (None, 149, 64)        │         25,408 │ ts_ConvBlock2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pca (InputLayer)          │ (None, 128)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_GlobalMaxPooling       │ (None, 64)             │              0 │ ts_ResBiGRU1[0][0]     │
# │ (GlobalMaxPooling1D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pca_BatchNorm             │ (None, 128)            │            512 │ pca[0][0]              │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ts_BatchNorm              │ (None, 64)             │            256 │ ts_GlobalMaxPooling[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pca_Dense (Dense)         │ (None, 64)             │          8,256 │ pca_BatchNorm[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 128)            │              0 │ ts_BatchNorm[0][0],    │
# │                           │                        │                │ pca_Dense[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ comb_Dense2 (Dense)       │ (None, 31)             │          3,999 │ concatenate[0][0]      │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 50,911 (198.87 KB)
#  Trainable params: 8,512 (33.25 KB)
#  Non-trainable params: 42,399 (165.62 KB)

# %%
optimiser3 = Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999, epsilon=1e-08, clipnorm=1.0)
combined_model5.compile(optimizer=optimiser3, loss='categorical_crossentropy', metrics=['accuracy'])
history_4 = combined_model5.fit(train_rr_ds, validation_data=val_rr_ds, epochs=50, verbose = 1, callbacks = [reduce_lr])
# Out:
# Epoch 1/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - accuracy: 0.9979 - loss: 0.0212 - val_accuracy: 0.7241 - val_loss: 1.1780 - learning_rate: 0.0010
# Epoch 2/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9983 - loss: 0.0202 - val_accuracy: 0.7220 - val_loss: 1.1757 - learning_rate: 0.0010
# Epoch 3/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9960 - loss: 0.0205 - val_accuracy: 0.7249 - val_loss: 1.1737 - learning_rate: 0.0010
# Epoch 4/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9967 - loss: 0.0200 - val_accuracy: 0.7256 - val_loss: 1.1712 - learning_rate: 0.0010
# Epoch 5/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9988 - loss: 0.0167 - val_accuracy: 0.7241 - val_loss: 1.1698 - learning_rate: 0.0010
# Epoch 6/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9973 - loss: 0.0173 - val_accuracy: 0.7284 - val_loss: 1.1727 - learning_rate: 0.0010
# Epoch 7/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9978 - loss: 0.0178 - val_accuracy: 0.7263 - val_loss: 1.1771 - learning_rate: 0.0010
# Epoch 8/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9969 - loss: 0.0170 - val_accuracy: 0.7256 - val_loss: 1.1802 - learning_rate: 0.0010
# Epoch 9/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9982 - loss: 0.0162 - val_accuracy: 0.7249 - val_loss: 1.1792 - learning_rate: 5.0000e-04
# Epoch 10/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9987 - loss: 0.0147 - val_accuracy: 0.7256 - val_loss: 1.1804 - learning_rate: 5.0000e-04
# Epoch 11/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9986 - loss: 0.0154 - val_accuracy: 0.7256 - val_loss: 1.1827 - learning_rate: 5.0000e-04
# Epoch 12/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9981 - loss: 0.0142 - val_accuracy: 0.7270 - val_loss: 1.1827 - learning_rate: 2.5000e-04
# Epoch 13/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9998 - loss: 0.0127 - val_accuracy: 0.7263 - val_loss: 1.1815 - learning_rate: 2.5000e-04
# Epoch 14/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9975 - loss: 0.0155 - val_accuracy: 0.7256 - val_loss: 1.1798 - learning_rate: 2.5000e-04
# Epoch 15/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9990 - loss: 0.0147 - val_accuracy: 0.7256 - val_loss: 1.1793 - learning_rate: 1.2500e-04
# Epoch 16/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9995 - loss: 0.0125 - val_accuracy: 0.7256 - val_loss: 1.1794 - learning_rate: 1.2500e-04
# Epoch 17/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9988 - loss: 0.0134 - val_accuracy: 0.7263 - val_loss: 1.1788 - learning_rate: 1.2500e-04
# Epoch 18/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9993 - loss: 0.0128 - val_accuracy: 0.7256 - val_loss: 1.1780 - learning_rate: 1.0000e-04
# Epoch 19/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9990 - loss: 0.0139 - val_accuracy: 0.7256 - val_loss: 1.1770 - learning_rate: 1.0000e-04
# Epoch 20/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9992 - loss: 0.0128 - val_accuracy: 0.7256 - val_loss: 1.1762 - learning_rate: 1.0000e-04
# Epoch 21/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9982 - loss: 0.0134 - val_accuracy: 0.7256 - val_loss: 1.1763 - learning_rate: 1.0000e-04
# Epoch 22/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9985 - loss: 0.0132 - val_accuracy: 0.7270 - val_loss: 1.1764 - learning_rate: 1.0000e-04
# Epoch 23/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9982 - loss: 0.0148 - val_accuracy: 0.7270 - val_loss: 1.1764 - learning_rate: 1.0000e-04
# Epoch 24/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9982 - loss: 0.0156 - val_accuracy: 0.7270 - val_loss: 1.1769 - learning_rate: 1.0000e-04
# Epoch 25/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9977 - loss: 0.0147 - val_accuracy: 0.7270 - val_loss: 1.1770 - learning_rate: 1.0000e-04
# Epoch 26/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9988 - loss: 0.0137 - val_accuracy: 0.7277 - val_loss: 1.1772 - learning_rate: 1.0000e-04
# Epoch 27/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9969 - loss: 0.0154 - val_accuracy: 0.7263 - val_loss: 1.1772 - learning_rate: 1.0000e-04
# Epoch 28/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9985 - loss: 0.0130 - val_accuracy: 0.7263 - val_loss: 1.1772 - learning_rate: 1.0000e-04
# Epoch 29/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9996 - loss: 0.0121 - val_accuracy: 0.7263 - val_loss: 1.1774 - learning_rate: 1.0000e-04
# Epoch 30/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9983 - loss: 0.0138 - val_accuracy: 0.7270 - val_loss: 1.1773 - learning_rate: 1.0000e-04
# Epoch 31/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9988 - loss: 0.0137 - val_accuracy: 0.7270 - val_loss: 1.1770 - learning_rate: 1.0000e-04
# Epoch 32/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9994 - loss: 0.0129 - val_accuracy: 0.7277 - val_loss: 1.1769 - learning_rate: 1.0000e-04
# Epoch 33/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9985 - loss: 0.0136 - val_accuracy: 0.7277 - val_loss: 1.1772 - learning_rate: 1.0000e-04
# Epoch 34/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9997 - loss: 0.0110 - val_accuracy: 0.7277 - val_loss: 1.1766 - learning_rate: 1.0000e-04
# Epoch 35/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9980 - loss: 0.0132 - val_accuracy: 0.7277 - val_loss: 1.1768 - learning_rate: 1.0000e-04
# Epoch 36/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9991 - loss: 0.0127 - val_accuracy: 0.7277 - val_loss: 1.1778 - learning_rate: 1.0000e-04
# Epoch 37/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9984 - loss: 0.0128 - val_accuracy: 0.7270 - val_loss: 1.1788 - learning_rate: 1.0000e-04
# Epoch 38/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9987 - loss: 0.0127 - val_accuracy: 0.7270 - val_loss: 1.1777 - learning_rate: 1.0000e-04
# Epoch 39/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9997 - loss: 0.0115 - val_accuracy: 0.7270 - val_loss: 1.1775 - learning_rate: 1.0000e-04
# Epoch 40/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9963 - loss: 0.0142 - val_accuracy: 0.7270 - val_loss: 1.1776 - learning_rate: 1.0000e-04
# Epoch 41/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9993 - loss: 0.0134 - val_accuracy: 0.7270 - val_loss: 1.1774 - learning_rate: 1.0000e-04
# Epoch 42/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9993 - loss: 0.0117 - val_accuracy: 0.7277 - val_loss: 1.1768 - learning_rate: 1.0000e-04
# Epoch 43/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9992 - loss: 0.0123 - val_accuracy: 0.7277 - val_loss: 1.1764 - learning_rate: 1.0000e-04
# Epoch 44/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9993 - loss: 0.0129 - val_accuracy: 0.7277 - val_loss: 1.1763 - learning_rate: 1.0000e-04
# Epoch 45/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9999 - loss: 0.0115 - val_accuracy: 0.7284 - val_loss: 1.1763 - learning_rate: 1.0000e-04
# Epoch 46/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9991 - loss: 0.0121 - val_accuracy: 0.7277 - val_loss: 1.1773 - learning_rate: 1.0000e-04
# Epoch 47/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9997 - loss: 0.0112 - val_accuracy: 0.7277 - val_loss: 1.1775 - learning_rate: 1.0000e-04
# Epoch 48/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9985 - loss: 0.0141 - val_accuracy: 0.7270 - val_loss: 1.1776 - learning_rate: 1.0000e-04
# Epoch 49/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9993 - loss: 0.0128 - val_accuracy: 0.7270 - val_loss: 1.1777 - learning_rate: 1.0000e-04
# Epoch 50/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9995 - loss: 0.0115 - val_accuracy: 0.7263 - val_loss: 1.1777 - learning_rate: 1.0000e-04

# %% [markdown]
# The model appears to be caught in a local minima. This was also the case for the pre-trained model.
